# %%
from IPython.display import Image

# %% [markdown]
# ## Tests

# %% [markdown]
# Pour le moment on récupère que les marqueurs avec chiffres et unité

# %%
doc_0 = {
    "leucocytes" : "5000/mL",
    "hematies": "<1000/mL"
}
doc_1 = {}
doc_2 = {}
doc_3 = {
    "creatinine": "70,8umol/L",
    "ckp-epi": "122,42ml/min/1.73m2",
    "transaminases sgpt": "28U/L"
}
doc_4 = {
    "hematie": "4,71T/L", #page 3 (hematologie)
    "hemoglobine": "13,5g/dL",
    "hematocrite": "42,2%",
    "vgm": "90fL",
    "tcmh": "28,7pg",
    "ccmh": "32,0g/dL",
    "leucocytes": "6400/mm3",
    "neutrophiles": "3283/mm3",
    "eosinophiles": "109/mm3",
    "basophiles": "32/mm3",
    "lymphocytes": "2522/mm3",
    "monocytes": "454/mm3",
    "plaquettes": "264000/mm3",
    "vmp": "11,1fL",
    "proteine c reactive": "<0,6mg/L", #page 4 (Biochime sanguine)
    "glycemie": "0,96g/L",
    "uree": "0,22g/L",
    "creatininemie": "8,3mg/L",
    "clairance calculée en creatine": "89mL/min",
    "dfg estimé selon l'équation ckd epi": "95mL/min/1,73m2",
    "sodium": "136mmol/L",
    "potassium": "4,4mmol/L",
    "calcium": "92mg/L",
    "ferritine": "22ng/mL",
    "transaminases": "20U/L",
    "transaminases": "11U/L", # page 5, pas sur la même page 
    "phosphatases alcalines": "43U/L",
    "gamma-gt": "13U/L",
    "anticorps toxo igg": "<0,13UI/mL", #page 6
    "tsh": "0,98mUI/L", #page 7
    "protides totaux": "77,0g/L",
    "albumine": "42,7g/L",
    "alpha1 globulines": "2,7g/L",
    "alpha2 globulines": "8,9g/L",
    "beta1 globulines": "5,4g/L",
    "beta2 globulines": "5,0g/L",
    "gamma globulines": "14,3g/L",
}
# voir avant parenthèses

doc_5 = {
    "leucocytes": "5,1G/L",
    "hematies": "3,99Téra/l",
    'hemoglobine': '12,5g/dL',
    "hematocrite": "37,2%",
    "volume globulaire moyen": "93fL",
    "tcmh": "31,3pg",
    "ccmh": "33,5g/dL",
    "idr": "13,0%",
    "neutrophile": "2,94G/L",
    "eosinophiles": "0,07G/L",
    "basophiles": "0,03G/L",
    "lymphocytes": "1,56G/L",
    "monocytes": "0,50G/L",
    "plaquettes x": "222G/L",
    "vitamine B12" : "339pg/ml",
    "ferritinex": "50ng/ml",
}
doc_6 = {}
doc_7 = {}
doc_8 = {}
doc_9 = {
    "leucocytes": "4.000/ml",
    "hematies": "4.000/ml"
}
doc_10 = {
    "glycemie a jeun": "0,89g/L",
    "cholesterol total": "1,57g/L",
    "hdl cholesterol": "0,31g/L",
    'ldl cholesterol': '1,10g/L',
    'triglycerides': '0,53g/L'
}
doc_11 = {}
doc_12 = {}
doc_12 = {}
doc_13 = {
    'creatinine': '6,8mg/L',
    'leucocytes': '1000/mL',
    'hematies': '1000/mL'
}
doc_14 = {}
doc_15 = {}
doc_16 = {}
doc_17 = {}
doc_18 = {
    "glycemie a jeun": "0,97g/L",
    'cholesterol total': '1,44g/L',
    "hdl cholesterol": "0,56g/L",
    "ldl cholesterol": "0,73 g/L",
    'triglycerides': '0,78g/L', 
    "gamma gt": "17U/L",
    'tsh': '2,15UI/mL', 
    'fsh': '6,57mUI/mL', 
    'lh': '8,5mUI/mL', 
    'estradiol': '22,8pg/mL', 
    'prolactine': '12,73ng/mL',
    "testosterone": "2,17mmoles/L"   
}
doc_19 = {
    "leucocytes": "13,34G/L",
    "erythrocytes": "4,61T/L",
    'hemoglobine': '13,8g/100ml',
    "hematocrite": "41,8%",
    "vgm": "91u3",
    "ccmh": "33,0g/100ml",
    'tcmh': '29,9pg', 
    "netrophiles": "9258/mm3",
    "eosinophiles": "0/mm3",
    "basophiles":"53/mm3",
    'lymphocytes': '3135/mm3', 
    'monocytes': '894/mm3',
    "plaquettes": "299G/L",
    "ferritine": "37ng/ml",
    "glycosurie": "0,12mmol/l",
    'tsh': '0,65mUI/L'
}
doc_20 = {
    "glycemie a jeun": "0,96g/L",
    'sodium': '138mmol/L', 
    'potassium': '4,6mmol/L', 
    'creatinine': '6,9mg/L',
    "albuminemie": "44g/L",
    "calcium": "101mg/L",
    'calcium corrige': '98mg/L', 
    'asat': '15U/L', 
    'alat': '12U/L',
    "gamma gt": "11U/L",
    'ferritine': '23ng/mL', 
    "cholesterol total": "2,17g/L",
    "hdl cholesterol": "0,62g/L",
    'ldl cholesterol': '1,31g/L', 
    'triglycerides': '1,55g/L',
    "protides totaux": "74,80g/L",
    "leucocytes": "6,910o//",
    "hematies":"4,351012/",
    "hemoglobine": "13,8g/dl",
    'hematocrite': '40,4%',
    "vgm": "92,9fl",
    'tcmh': '31,7pg',
    "ccmh": "34,1g/dl",
    'lymphocytes': '39,69%', 
    'monocytes': '7,3%',
    "plaquettes": "29010%/",
    'folates': '7,60ng/ml',
    "vitamine b12": "230pg/ml",
    "leucocyturie": "1000/ml",
    "hematurie": "3000/ml",
}

ref_docs = [doc_0, doc_1, doc_2, doc_3, doc_4, doc_5, doc_6, doc_7, doc_8, doc_9, doc_10, doc_11, doc_12, doc_13, doc_14, doc_15, doc_16, doc_17, doc_18, doc_19, doc_20]

# %%
'''result_docs = []
for i in range(21):
    dictionnaire = extract_values(docs[i])
    result_docs.append(dictionnaire)
print(result_docs)'''
# Out:
# 'result_docs = []\nfor i in range(21):\n    dictionnaire = extract_values(docs[i])\n    result_docs.append(dictionnaire)\nprint(result_docs)'

# %%
def comparer_dictionnaires(ref, result):
    elements_non_communs = {}
    for cle, valeur in ref.items():
        if cle not in result or result[cle] != valeur:
            elements_non_communs[cle] = valeur
    return elements_non_communs


def f2(ref, result):
    well_predicted = 0
    for cle, valeur in result.items():
        if cle in ref and valeur == ref[cle] :
            well_predicted += 1
        else:
            print(cle, valeur)
    return well_predicted

def tests_docs(ref_tests, results):
    '''
        ref_tests: list defined above
        results: list of dict of values found
    '''
    if len(ref_tests) != len(results):
        print('Not the same length')
        return False
    
    nb_equals = 0
    nb_total = 0
    for i in range(len(results)):
        nb_total += len(results[i])
        if results[i] == ref_tests[i]:
            nb_equals += len(results[i])
        else:
            print(f'################Document of index {i} ################')
            nb_equals += f2(ref_tests[i], results[i])
            
    percentage = (nb_equals / nb_total) * 100
    print(f'Percentage of success: {percentage}%')
    return True

# %%
result_docs = [{'leucocytes': '5000/mL', 'hematies': '<1000/mL'}, {}, {}, {'creatinine': '70,8umol/L'}, {'hematies': '4,71g/dL', 'hematocrite': '42,2%', 'vgm': '90fL', 'tcmh': '28,7pg', 'ccmh': '32,0g/dL', 'leucocytes': '6400/mm3', 'plaquettes': '264000/mm3', 'vmp': '11,1fL', 'crp': '<0,6mg/L', 'uree': '0,22g/L', 'creatinine': '89mL/min', 'sodium': '136mmol/L', 'potassium': '4,4mmol/L', 'calcium': '92mg/L', 'ferritine': '22ng/mL', 'titre': '<0,25U/mL', 'tsh': '0,98mUI/L', 'albumine': '55,50%', 'globulines': '18,60%'}, {'leucocytes': '5,1G/L', 'hemoglobine': '12,5g/dL', 'hematocrite': '37,2%', 'volume': '93fL', 'tcmh': '31,3pg', 'ccmh': '33,5g/dL', 'idr': '13,0%', 'lymphocytes': '30,6%', 'monocytes': '9,8%', 'plaquettes': '222G/L'}, {}, {}, {}, {'leucocytes': '4.000/ml', 'hematies': '4.000/ml'}, {'cholesterol': '1,10g/L', 'triglycerides': '0,53g/L'}, {}, {}, {'creatinine': '6,8mg/L', 'leucocytes': '<1000/mL', 'hematies': '<1000/mL'}, {}, {}, {}, {}, {'cholesterol': '1,44/', 'triglycerides': '0,78/', 'tsh': '2,15/', 'fsh': '6,57mUI/mL', 'lh': '8,5mUI/mL', 'estradiol': '22,8pg/mL', 'prolactine': '12,73ng/mL'}, {'leucocytes': '13.34G/L', 'hemoglobine': '13,8g/100ml', 'hematocrite': '41,8%', 'vgm': '91g/100ml', 'tcmh': '29,9pg', 'lymphocytes': '23.5%', 'monocytes': '6.7%', 'plaquettes': '299G/L', 'ferritine': '37ng/ml', 'tsh': '0,65mUI/L', 'titre': '40,3UI/ml'}, {'sodium': '138mmol/L', 'potassium': '4,6mmol/L', 'creatinine': '6,9mg/L', 'calcium': '98mg/L', 'asat': '15U/L', 'alat': '12U/L', 'ferritine': '23ng/mL', 'cholesterol': '1,31g/L', 'triglycerides': '1,55g/L', 'hemoglobine': '13,8g/dl', 'hematocrite': '40,4%', 'vgm': '92,9fl', 'tcmh': '31,7pg', 'ccmh': '34,1g/dl', 'lymphocytes': '39,69%', 'folates': '7,60ng/mL', 'leucocyturie': '1000ml', 'proteines': '74,8g/l'}]

# %%
tests_docs(ref_docs, result_docs)
# Out:
# ################Document of index 3 ################
# ################Document of index 4 ################
# hematies 4,71g/dL
# crp <0,6mg/L
# creatinine 89mL/min
# titre <0,25U/mL
# albumine 55,50%
# globulines 18,60%
# ################Document of index 5 ################
# volume 93fL
# lymphocytes 30,6%
# monocytes 9,8%
# plaquettes 222G/L
# ################Document of index 10 ################
# cholesterol 1,10g/L
# ################Document of index 13 ################
# leucocytes <1000/mL
# hematies <1000/mL
# ################Document of index 18 ################
# cholesterol 1,44/
# triglycerides 0,78/
# tsh 2,15/
# ################Document of index 19 ################
# leucocytes 13.34G/L
# vgm 91g/100ml
# lymphocytes 23.5%
# monocytes 6.7%
# titre 40,3UI/ml
# ################Document of index 20 ################
# calcium 98mg/L
# cholesterol 1,31g/L
# folates 7,60ng/mL
# leucocyturie 1000ml
# proteines 74,8g/l
# Percentage of success: 65.33333333333333%
# True
