# %%
from IPython.display import Image

# %% [markdown]
# ## Tests

# %% [markdown]
# Pour le moment on récupère que les marqueurs avec chiffres et unité

# %%
doc_0 = {
    "leucocytes" : "5000/mL",
    "hematies": "<1000/mL"
}
doc_1 = {}
doc_2 = {}
doc_3 = {
    "creatinine": "70,8umol/L",
    "ckp-epi": "122,42ml/min/1.73m2",
    "transaminases sgpt": "28U/L"
}
doc_4 = {
    "hematie": "4,71T/L", #page 3 (hematologie)
    "hemoglobine": "13,5g/dL",
    "hematocrite": "42,2%",
    "vgm": "90fL",
    "tcmh": "28,7pg",
    "ccmh": "32,0g/dL",
    "leucocytes": "6400/mm3",
    "neutrophiles": "3283/mm3",
    "eosinophiles": "109/mm3",
    "basophiles": "32/mm3",
    "lymphocytes": "2522/mm3",
    "monocytes": "454/mm3",
    "plaquettes": "264000/mm3",
    "vmp": "11,1fL",
    "crp": "<0,6mg/L", #page 4 (Biochime sanguine)
    "glycemie": "0,96g/L",
    "uree": "0,22g/L",
    "creatininemie": "8,3mg/L",
    "clairance calculée en creatine": "89mL/min",
    "dfg estimé selon l'équation ckd epi": "95mL/min/1,73m2",
    "sodium": "136mmol/L",
    "potassium": "4,4mmol/L",
    "calcium": "92mg/L",
    "ferritine": "22ng/mL",
    "transaminases": "20U/L",
    "transaminases": "11U/L", # page 5, pas sur la même page 
    "phosphatases alcalines": "43U/L",
    "gamma-gt": "13U/L",
    "anticorps toxo igg": "<0,13UI/mL", #page 6
    "tsh": "0,98mUI/L", #page 7
    "protides totaux": "77,0g/L",
    "albumine": "42,7g/L",
}
# voir avant parenthèses

doc_5 = {
    "leucocytes": "5,1G/L",
    "hematies": "3,99Téra/l",
    'hemoglobine': '12,5g/dL',
    "hematocrite": "37,2%",
    "volume globulaire moyen": "93fL",
    "tcmh": "31,3pg",
    "ccmh": "33,5g/dL",
    "idr": "13,0%",
    "neutrophile": "2,94G/L",
    "eosinophiles": "0,07G/L",
    "basophiles": "0,03G/L",
    "lymphocytes": "1,56G/L",
    "monocytes": "0,50G/L",
    "plaquettes": "222G/L",
    "vitamine B12" : "339pg/ml",
    "ferritinex": "50ng/ml",
}
doc_6 = {}
doc_7 = {}
doc_8 = {}
doc_9 = {
    "leucocytes": "4.000/ml",
    "hematies": "4.000/ml"
}
doc_10 = {
    "glycemie a jeun": "0,89g/L",
    "cholesterol total": "1,57g/L",
    "hdl cholesterol": "0,31g/L",
    'ldl cholesterol': '1,10g/L',
    'triglycerides': '0,53g/L'
}
doc_11 = {}
doc_12 = {}
doc_12 = {}
doc_13 = {
    'creatinine': '6,8mg/L',
    'leucocytes': '<1000/mL',
    'hematies': '<1000/mL'
}
doc_14 = {}
doc_15 = {}
doc_16 = {}
doc_17 = {}
doc_18 = {
    'cholesterol total': '1,44g/L',
    "hdl cholesterol": "0,56g/L",
    "ldl cholesterol": "0,73 g/L",
    'triglycerides': '0,78g/L', 
    "gamma gt": "17U/L",
    'tsh': '2,15UI/mL', 
    'fsh': '6,57mUI/mL', 
    'lh': '8,5mUI/mL', 
    'estradiol': '22,8pg/mL', 
    'prolactine': '12,73ng/mL',
    "testosterone": "2,17mmoles/L"   
}
doc_19 = {
    "leucocytes": "13.34G/L",
    "erythrocytes": "4,61T/L",
    'hemoglobine': '13,8g/100ml',
    "hematocrite": "41,8%",
    "vgm": "91u3",
    "ccmh": "33,0g/100ml",
    'tcmh': '29,9pg', 
    "netrophiles": "9258/mm3",
    "eosinophiles": "0/mm3",
    "basophiles":"53/mm3",
    'lymphocytes': '3135/mm3', 
    'monocytes': '894/mm3',
    "plaquettes": "299G/L",
    "ferritine": "37ng/ml",
    "glycosurie": "0,12mmol/l",
    'tsh': '0,65mUI/L'
}
doc_20 = {
    'sodium': '138mmol/L', 
    'potassium': '4,6mmol/L', 
    'creatinine': '6,9mg/L',
    "albuminemie": "44g/L",
    "calcium": "101mg/L",
    'calcium corrige': '98mg/L', 
    'asat': '15U/L', 
    'alat': '12U/L',
    "gamma gt": "11U/L",
    'ferritine': '23ng/mL', 
    "cholesterol total": "2,17g/L",
    "hdl": "0,62g/L",
    'ldl': '1,31g/L', 
    'triglycerides': '1,55g/L',
    "protides totaux": "74,80g/l",
    "leucocytes": "6,910o//",
    "hematies":"4,351012/",
    "hemoglobine": "13,8g/dl",
    'hematocrite': '40,4%',
    "vgm": "92,9fl",
    'tcmh': '31,7pg',
    "ccmh": "34,1g/dl",
    'lymphocytes': '39,69%', 
    'monocytes': '7,3%',
    "plaquettes": "29010%/",
    'folates': '7,60ng/ml',
    "vitamine b12": "230pg/ml",
    "leucocyturie": "1000/ml",
    "hematurie": "3000/ml",
    "proteine": "74,8g/l"
}

doc_21 = {}

doc_22 = {}

doc_23 = {}

doc_24 = {}

doc_25 = {
    "hematies" : "4,45T/L",
    "hemoglobine" : "13,1g/dl",
    "hematocrite" : "39,0%",
    "vgm": "88fL",
    "tcmh": "29,4pg",
    "ccmh": "33,6g/dL",
    "leucocytes": "4,6Giga/L",
    "asat": "25U/L",
    "alat": "23U/L",
    "lymphocytes": "1,33Giga/L",
    "monocytes": "0,38Giga/L",
    "sodium": "138mmol/L",
    "potassium": "4,4mmol/L",
    "creatinine": "57umol/L",
    "ggt": "10UI/L",
    "hdl": "1,20mmol/L",
    "ldl": "1,96mmol/L",
    "triglycerides": "1,13mmol/l",
    "tsh": "2,605mUI/L",
    "leucocytes": "<000/mL",
    "hematies": "4400/mL",
    "bilirubine": "5,9umol/L"
}

doc_26 = {}

doc_27 = {}

doc_28 = {
    "hematies": "5,01M/mm3",
    "hemoglobine": "12,1g/100mL",
    "hemotocrite": "39,4%",
    "tcmh": "24,2picog.",
    "ccmh": "30,7g/100mL",
    "vgm": "77u3",
    "leucocytes": "5530/mm3",
    "lymphocytes": "879/mm3",
    "monocytes": "658/mm3",
    "plaquettes": "246000/mm3",
    "asat": "12UI/L",
    "alat": "10UI/L",
    "phosphatases": "55UI/L",
    "uree": "0,20g/L",
    "creatinine": "5,9mg/L",
    "sodium": "142mEq/L",
    "potassium": "5,3mEg/L",
    "chlore": "105mEg/L",
    "bilirubine": "4,8mg/L"
}

doc_29 = {
    "hematies": "4,71T/L",
    "hemoglobine": "14,1g/dL",
    "hematocrite": "42,8%",
    "vgm": "91fL",
    "tcmh": "29,9pg",
    "ccmh": "32,9g/dL",
    "ldr": "14,0%",
    "leucocytes": "7,64G/L",
    "lymphocytes": "3,23G/L",
    "monocytes": "0.59G/L",
    "plaquettes": "293G/L",
    "vpm": "11,0fL",
    "glycemie": "1,20G/L",
    "a1c": "6,0%",
    "cholesterol": "2,27g/L",
    "hdl": "0,70g/L",
    "ldl": "1,25g/L",
    "triglycerides": "1,58g/L",
    "sodium" : "143mmol/L",
    "potassium": '4,8mmol/L',
    "protéinurie": "0,09g/L",
    "creatinine": "9360umol/L"
}

doc_30 = {
    "leucocytes": " 5,89G/l",
    "erythrocytes": "4,59T/l",
    "hemoglobine": "13,7g/100ml",
    "hematocrite": "40,4%",
    "vgm": "88u3",
    "ccmh": "33,9g/100ml",
    "tmch": "29,8pg",
    "lymphocyte": "35,8%",
    "monocytes": "5,4%",
    "plaquettes": '247G/l',
    "uret": "0,24g/l", 
    "creatinine": "8,5mg/l",
    "cholesterol": "1,63g/l",
    "hdl": "0,64g/l",
    "ldl": "0,90g/l",
    "triglycerides": "0,46g/l",
    "sodium": "138mEq/l",
    "potassium": "4,1mEq/l",
    "chlore": "104mEg/l",
    "ferritine": "41neg/ml",
    "asat": "20U/l",
    "alat": "24U/l",
}

doc_31 = {
    "hematies": "4,65T/L",
    "hemoglobine": "13,4g/dL",
    "hematocrite": "39,7%",
    "vgm": "85fL",
    "tcmh": "28,8pg",
    "ccmh":"33,8%",
    "idr": "12,0%",
    "leucocytes": "7,39G/L",
    "lymphocytes": "1,22G/L",
    "monocytes": "0,51G/L",
    "plaquettes": "224G/L",
    "vpm": "9,5fL",
    "glycemie": "0,94g/L",
    "creatinine": "7,2mg/L",
    "cholesterol": "1,92g/L",
    "hdl": "0,48g/L",
    "ldl": "1,23g/L",
    "triglycerides": "1,06g/L",
    "sodium": "137mmol/L",
    "potassium": "4,0mmol/L",
    "alat": '31U/L',
    "asat": '29U/L',
    "ggt": "19U/L",
    "phosphatases": "79UI/L",
    "ferritine": "48,0ng/nL",
    "tsh": "1,160mUI/L",
    "albumine": "43,30g/L",
    "proteines": "77g/L",
}

doc_32 = {
    "hematies": "4,57Tera/L",
    "hemoglobine": "12,9g/dL",
    "hematocrite": "39,0%",
    "vgm": "85,3fL",
    "tcmh": "28,2picog",
    "ccmh":"33,1g/dl",
    "leucocytes": "7,67Giga/L",
    "lymphocytes": "1,62Giga/L",
    "monocytes": "0,47Giga/L",
    "plaquettes": "285Giga/L",
    "sgot": "15,9UI/L",
    "sgpt": "15,6UI/L",
    "creatinine": "7,4mg/L",
    "triglycerides": "0,78g/L",
    "cholesterol": "1,81g/L",
    "hdl": "0,49g/L",
    "ldl": "1,16g/L",
    "ferritine": "22,0ug/L",
    "proteine": "1,0mg/L",
    "tsh": "1,91mUI/L",
}

doc_33 = {
    "hematies": "5,35T/L",
    "hemoglobine": "15,5g/dL",
    "hematocrite": "45,1%",
    "vgm": "84fL",
    "tcmh": "28,9pg",
    "ccmh":"34,3g/dl",
    "leucocytes": "8,90G/L",
    "lymphocytes": "2,95G/L",
    "monocytes": "0,45G/L",
    "plaquettes": "255G/L",
    "creatinine": "104umol/L",
    "asat": "27U/L",
    "alat": "33U/L",
    "tsh": "0,88mUI/L",
    "testosterone": "21,87nmol/L",
    "psa": "0,328ug/L",
}

doc_34 = {}

doc_35 = {
    "hematies": "4100000/mm3",
    "hemoglobine": "13,4g/100mL",
    "hematocrite": "39,0%",
    "tcmh": "32,7picog",
    "ccmh":"34,4%",
    "leucocytes": "8900/mm3",
    "lymphocytes": "2003/mm3",
    "monocytes": "543/mm3",
    "plaquettes": "301000/mm3",
}

doc_36 = {
    "hematies": "4880000/mm3",
    "hemoglobine": "14,3g/100mL",
    "hematocrite": "43,9%",
    "tcmh": "29,3pg",
    "ccmh":"33%",
    "leucocytes": "4000/mm3",
    "lymphocytes": "2100/mm3",
    "monocytes": "372/mm3",
    "plaquettes": "333000/mm3",
    "vpm": "9,8fL",
    "proteine": "1,4mg/L",
    "glycemie": "0,78g/L",
    "uree": "0,26g/L",
    "creatinine": "8,3mg/L",
    "cholesterol": "1,96g/L",
    "hdl": "0,65g/L",
    "ldl": "1,20g/L",
    "trigycerides": "0,56g/L",
    "sodium": "142mmol/L",
    "potassium": "4,4mmol/L",
    "chlore": "103mmol/L",
    "asat": "26U/L",
    "alat": "27U/L",
    "phosphatases": "87U/L",
}

doc_37, doc_38 = {}, {}

doc_39 = {
    "hematies": "1000/mm3",
    "leucocytes": "204/mm3",
}

doc_40 = {
    "tsh": "2,967mUI/L",
    "testosterone": "0,62nmol/l",
    "oestradiol": "017pmol/l",
    "lh": "5,10UI/l",
    "fsh": "18,63UI/l",
    "prolactine": "285,1mUI/l",
    
}

doc_41 = {}
doc_42 = {}
doc_43 = {}
doc_44 = {}
doc_45 = {}
doc_46 = {}
doc_47 = {}
doc_48 = {}
doc_49 = {
    "hematies": "5,21M/mm3",
    "hemoglobine": "15,7g/100mL",
    "hematocrite": "48,2%",
    "tcmh": "30,1picog",
    "ccmh":"32,6g/100mL",
    "vgm": "92u3",
    "leucocytes": "4580/mm3",
    "lymphocytes": "1969/mm3",
    "monocytes": "412/mm3",
    "plaquettes": "196000/mm3",
    "asat" : "27UI/L",
    "alat" : "34UI/L",
    "uree" : "0,29g/L",
    "creatinine" : "12,2mg/L",
    "sodium": "141mEq/L",
    "potassium": "4,9mEq/L",
    "chlore": "105mEq/L",
    "triglycerides": "1,65g/L",
    "cholesterol": "1,72g/L",
    "hdl": "0,60g/L",
    "ldl": "0,79g/L",
    "tsh": "2,10uUI/ml"
}

doc_50 = {
    "cholesterol": "5,00mmol/L",
    "hdl": "1,26mmol/L",
    "ldl": "3,21mmol/L",
    "triglycerides": "1,17mmol/L",
}

doc_51 = {}
doc_52 = {}
doc_53 = {}
doc_54 = {
    "leucocytes": "1540/mL",
    "hematies": "<1000/mL"
}
doc_55 = {}
doc_56 = {}
doc_57 = {
    "creatinine urinaire": "695mg/L",
    "microalbuminurie": "3,3mg/L"
}

doc_58 = {
    "glycemie": "0,88g/L",
    "cholesterol": "1,53g/L",
    "hdl": "0,71g/L",
    "ldl" : "0,69g/L",
    "triglycerides": "0,64g/L"
}
 
doc_59 = {}
doc_60 = {
    "leucocytes": "14000/ml",
    "hematies": "6000/ml"
}

ref_docs = [doc_0, doc_1, doc_2, doc_3, doc_4, doc_5, doc_6, doc_7, doc_8, doc_9, 
            doc_10, doc_11, doc_12, doc_13, doc_14, doc_15, doc_16, doc_17, doc_18, doc_19, 
            doc_20, doc_21, doc_22, doc_23, doc_24, doc_25, doc_26, doc_27, doc_28, doc_29,
            doc_30, doc_31, doc_32, doc_33, doc_34, doc_35, doc_36, doc_37, doc_38, doc_39,
            doc_40, doc_41, doc_42, doc_43, doc_44, doc_45, doc_46, doc_47, doc_48, doc_49,
            doc_50, doc_51, doc_52, doc_53, doc_54, doc_55, doc_56, doc_57, doc_58, doc_59,
            doc_60]

# %%
'''result_docs = []
for i in range(21):
    dictionnaire = extract_values(docs[i])
    result_docs.append(dictionnaire)
print(result_docs)'''
# Out:
# 'result_docs = []\nfor i in range(21):\n    dictionnaire = extract_values(docs[i])\n    result_docs.append(dictionnaire)\nprint(result_docs)'

# %%
def comparer_dictionnaires(ref, result):
    elements_non_communs = {}
    for cle, valeur in ref.items():
        if cle not in result or result[cle] != valeur:
            elements_non_communs[cle] = valeur
    return elements_non_communs


def f2(ref, result):
    well_predicted = 0
    for cle, valeur in result.items():
        if cle in ref and valeur.lower() == ref[cle].lower() :
            well_predicted += 1
        else:
            print(cle, valeur)
    return well_predicted

def tests_docs(ref_tests, results):
    '''
        ref_tests: list defined above
        results: list of dict of values found
    '''
    if len(ref_tests) != len(results):
        print('Not the same length')
        return False
    
    nb_equals = 0
    nb_total = 0
    for i in range(len(results)):
        nb_total += len(results[i])
        if results[i] == ref_tests[i]:
            nb_equals += len(results[i])
        else:
            print(f'################ Document of index {i} ################')
            nb_equals += f2(ref_tests[i], results[i])
            
    percentage = (nb_equals / nb_total) * 100
    print(f'Percentage of success: {percentage}%')
    return True

# %%
result_docs = [{'leucocytes': '5000/mL', 'hematies': '<1000/mL'}, {}, {}, {'creatinine': '70,8umol/L'}, {'hematies': '4,71T/L', 'hemoglobine': '13,5g/dL', 'hematocrite': '42,2%', 'vgm': '90fL', 'tcmh': '28,7pg', 'ccmh': '32,0g/dL', 'leucocytes': '6400/mm3', 'plaquettes': '264000/mm3', 'crp': '<0,6mg/L', 'uree': '0,22g/L', 'creatinine': '89mL/min', 'sodium': '136mmol/L', 'potassium': '4,4mmol/L', 'calcium': '92mg/L', 'ferritine': '22ng/mL', 'titre': '<0,25U/mL', 'tsh': '0,98mUI/L', 'albumine': '55,50%'}, {'leucocytes': '5,1G/L', 'hemoglobine': '12,5%', 'volume': '93fL', 'tcmh': '31,3pg', 'ccmh': '33,5%', 'lymphocytes': '30,6%', 'monocytes': '9,8%', 'plaquettes': '222G/L'}, {}, {}, {}, {'leucocytes': '4.000/ml', 'hematies': '4.000/ml'}, {'cholesterol': '1,10g/L', 'triglycerides': '0,53g/L'}, {}, {}, {'creatinine': '6,8mg/L', 'leucocytes': '<1000/mL', 'hematies': '<1000/mL'}, {}, {}, {}, {}, {'cholesterol': '1,44/', 'triglycerides': '0,78/', 'tsh': '2,15/', 'fsh': '6,57/', 'lh': '8,5/', 'prolactine': '12,73ng/mL', 'testosterone': '2,17/'}, {'leucocytes': '13.34G/L', 'erythrocytes': '4.61T/L', 'hemoglobine': '13,8%', 'vgm': '91u3', 'ccmh': '33,0g/100ml', 'tcmh': '29,9pg', 'lymphocytes': '23.5%', 'monocytes': '6.7%', 'plaquettes': '299G/L', 'ferritine': '37ng/ml', 'tsh': '0,65mUI/L', 'titre': '40,3UI/ml'}, {'sodium': '138mmol/L', 'potassium': '4,6mmol/L', 'creatinine': '6,9mg/L', 'calcium': '98mg/L', 'asat': '15U/L', 'alat': '12U/L', 'ferritine': '23ng/mL', 'cholesterol': '1,31g/L', 'triglycerides': '1,55g/L', 'hemoglobine': '13,8%', 'vgm': '92,9fl', 'tcmh': '31,7pg', 'ccmh': '34,1g/dl', 'lymphocytes': '39,69%', 'folates': '7,60ng/mL', 'leucocyturie': '1000/', 'proteines': '74,8g/l'}, {}, {}, {}, {}, {'hematies': '4,45T/L', 'hemoglobine': '13,1%', 'vgm': '88fL', 'tcmh': '29,4pg', 'ccmh': '31.0g/dL', 'leucocytes': '<000/mL', 'lymphocytes': '29,0%', 'monocytes': '8,3%', 'sodium': '138mmol/L', 'creatinine': '57umol/L', 'asat': '25U/L', 'alat': '23U/L', 'bilirubine': '3,5umol/L', 'cholesterol': '1,96mmol/L', 'triglycerides': '1,13mmol/L', 'tsh': '2,605mUI/L'}, {}, {}, {'hemoglobine': '12,1g/100mL', 'tcmh': '24,2picog.', 'ccmh': '30,7mL', 'vgm': '79u3', 'leucocytes': '55303', 'lymphocytes': '15,9%', 'monocytes': '11,9%', 'plaquettes': '246000/mm3', 'bilirubine': '4,8mg/L', 'uree': '0,20g/L', 'creatinine': '5,9mg/L', 'sodium': '142mEq/L', 'potassium': '5,3mEq/L', 'chlore': '105mEq/L'}, {'hematies': '4,71T/L', 'hemoglobine': '6,0%', 'hematocrite': '91fL', 'vgm': '29,9pg', 'tcmh': '32,9g/dL', 'ccmh': '14,0%', 'leucocytes': '7,64G/L', 'lymphocytes': '7,7%', 'plaquettes': '293G/L', 'cholesterol': '1,25g/L', 'triglycerides': '1,58g/L', 'sodium': '143mmol/L', 'potassium': '4,8mmol/L', 'creatinine': '9360umol/L'}, {'leucocytes': '5.89G/l', 'erythrocytes': '4.59T/l', 'hemoglobine': '13,7%', 'vgm': '88u3', 'ccmh': '33,9g/100ml', 'tcmh': '29,8pg', 'lymphocytes': '35.8%', 'monocytes': '5.4%', 'plaquettes': '247G/l', 'uree': '0,24g/l', 'creatinine': '8,5mg/l', 'cholesterol': '1,63g/l', 'triglycerides': '>3.4g/l'}, {'hematies': '4,65T/L', 'hemoglobine': '13,4g/dL', 'hematocrite': '39,7%', 'vgm': '85fL', 'tcmh': '28,8pg', 'ccmh': '33,8%', 'leucocytes': '7,39G/L', 'monocytes': '0,51G/L', 'plaquettes': '224G/L', 'creatinine': '7,2mg/L', 'cholesterol': '1,23g/L', 'triglycerides': '1,06g/L', 'sodium': '137mmol/L', 'potassium': '4,0mmol/L', 'alat': '31U/L', 'asat': '29U/L', 'ferritine': '48,0ng/mL', 'folates': '5,0ng/mL', 'tsh': '1,160mUI/L', 'titre': '0,13U/mL', 'proteines': '77g/L'}, {'hemoglobine': '12,9%', 'vgm': '85,3fL', 'ccmh': '33,1g/dl', 'leucocytes': '7,67Giga/L', 'lymphocytes': '1,62Giga/L', 'monocytes': '0,47Giga/L', 'plaquettes': '285Giga/L', 'creatinine': '7,4mg/L', 'triglycerides': '0,78g/L', 'cholesterol': '1,16g/L', 'ferritine': '22,0ug/L', 'tsh': '1,91mUI/L'}, {'hematies': '5,35T/L', 'hemoglobine': '15,5%', 'vgm': '84fL', 'tcmh': '28,9pg', 'ccmh': '34,3g/dL', 'leucocytes': '8,90G/L', 'lymphocytes': '2,95G/L', 'monocytes': '5,0%', 'plaquettes': '205G/L', 'creatinine': '104umol/L', 'alat': '33U/L', 'tsh': '0,88mUI/L', 'testosterone': '21,87nmol/L'}, {}, {'hematies': '4100000/mm3', 'hemoglobine': '13,4g/100mL', 'hematocrite': '39,0%', 'vgm': '953', 'tcmh': '32,7%', 'leucocytes': '8900/mm3', 'lymphocytes': '22,5%', 'monocytes': '6,1%', 'plaquettes': '301000/mm3'}, {'hemoglobine': '14,3g/100mL', 'hematocrite': '43,9%', 'vgm': '903', 'tcmh': '29,3pg', 'leucocytes': '4000/mm3', 'lymphocytes': '52,5%', 'monocytes': '9,3%', 'plaquettes': '333000/mm3', 'crp': '1,4mg/L', 'uree': '0,26g/L', 'creatinine': '8,3mg/L', 'cholesterol': '1,20g/L', 'triglycerides': '0,56g/L', 'sodium': '142mmol/L', 'potassium': '4,4mmol/L', 'chlore': '103mmol/L', 'asat': '26U/L', 'alat': '27U/L', 'bilirubine': '2,5mg/L'}, {}, {}, {'leucocytes': '204/mm3'}, {'tsh': '2,967mUI/L', 'testosterone': '0,62nmol/l'}, {}, {}, {}, {}, {}, {}, {}, {}, {'hemoglobine': '15,7%', 'tcmh': '30,1picog.', 'ccmh': '32,6mL', 'vgm': '92u3', 'leucocytes': '4580/mm3', 'lymphocytes': '43,0%', 'monocytes': '9,0%', 'plaquettes': '196000/mm3', 'uree': '0,29g/L', 'creatinine': '12,2mg/L', 'sodium': '141mEq/L', 'potassium': '4,9mEq/L', 'chlore': '105mEq/L', 'triglycerides': '1,65g/L', 'cholesterol': '0,79g/L'}, {'cholesterol': '5,00mmol/L', 'triglycerides': '1,17mmol/L'}, {}, {}, {}, {'leucocytes': '5401', 'hematies': '<11'}, {}, {}, {'creatinine': '695mg/L', 'microalbuminurie': '3,3mg/L'}, {'cholesterol': '0,69g/L', 'triglycerides': '0,64g/L'}, {}, {'leucocytes': '14000/ml', 'hematies': '6000/ml'}]

# %%
tests_docs(ref_docs, result_docs)
# Out:
# ################ Document of index 3 ################
# ################ Document of index 4 ################
# hematies 4,71T/L
# creatinine 89mL/min
# titre <0,25U/mL
# albumine 55,50%
# ################ Document of index 5 ################
# hemoglobine 12,5%
# volume 93fL
# ccmh 33,5%
# lymphocytes 30,6%
# monocytes 9,8%
# ################ Document of index 10 ################
# cholesterol 1,10g/L
# ################ Document of index 18 ################
# cholesterol 1,44/
# triglycerides 0,78/
# tsh 2,15/
# fsh 6,57/
# lh 8,5/
# testosterone 2,17/
# ################ Document of index 19 ################
# erythrocytes 4.61T/L
# hemoglobine 13,8%
# lymphocytes 23.5%
# monocytes 6.7%
# titre 40,3UI/ml
# ################ Document of index 20 ################
# calcium 98mg/L
# cholesterol 1,31g/L
# hemoglobine 13,8%
# leucocyturie 1000/
# proteines 74,8g/l
# ################ Document of index 25 ################
# hematies 4,45T/L
# hemoglobine 13,1%
# ccmh 31.0g/dL
# ...
