# %%
import json
import pandas as pd
from unidecode import unidecode
import re

#with open('data/subset_epita.json') as f:
with open('data/export_epita.json') as f:
    data = json.load(f)
    
def get_docs_from_id(id):
    docs = []
    for o in data:
        if o['document_type_id'] == id:
            docs.append(o)
    return docs

datas = get_docs_from_id(8)

def preprocess(word):
    lower = str.lower(word)
    normalized = unidecode(lower)
    punc = '''!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~'''
    for ele in normalized:
        if ele in punc:
            normalized = normalized.replace(ele, "")
    return normalized

def flatten(l):
    return [item for sublist in l for item in sublist]

# %% [markdown]
# # Récupérer les mots par paragraphe

# %%
def abs(a, b):
    r = a - b
    if r < 0:
        return -r
    return r

def regrouper_mots_par_hauteur(doc, tolerance):
    mots_regroupes = []
    
    keys = list(doc.keys())
    keys.pop()
    keys.pop()
    for key in keys:
        page = {}
        lines = doc[key]
        for line in lines:
            for w in line['line']['words']:
                hauteur = w['top']
                found = False
                for h in page:
                    if abs(h, hauteur) <= tolerance:
                        found = True
                        page[h].append(w['text'])
                        break
                if found == True:
                    continue
                if hauteur not in page:
                    page[hauteur] = []
                page[hauteur].append(w['text'])
        mots_regroupes.append(page)
    return mots_regroupes

tolerance = 0.02
docs = []

for doc in datas:
    resultat = regrouper_mots_par_hauteur(doc, tolerance)
    docs.append(resultat)

# Afficher les groupes de mots
doc = docs[4]
for page in doc:
    print("@@@@@@@@@@@@@@@@")
    for hauteur, mots in page.items():
        print(mots)
# Out:
# @@@@@@@@@@@@@@@@
# ['Mon', 'Dec', '21', '11:08:53', '2020', 'P.', '1', 'LE', 'LABO']
# ['LE', 'LABO', 'REPUBLIQUE', 'LABORATOIRE', 'DE', 'BIOLOGIE', 'MEDICALE']
# ['2', 'BOULEVARD', 'DE', 'MAGENTA', '75010', 'PARIS']
# ['Tel:', '0153388899', 'Fax:', '0153388891']
# ['Dr', 'Pasca:', 'AMRAM', 'Dr', 'Manon', 'CORGIAT', 'Dr', 'Frédérique', 'DUIGOU-THOUVENEL', 'Dr', 'Fabienne', 'LAUPRETRE', 'Dr', 'Brigitte', 'PORTE', 'Médecin', 'Biologiste', 'Pharmacien', 'biologiste', 'Pharmacien', 'Biologiste', 'Pharmacien', 'Biologiste', 'Médecin', 'Biologiste']
# ['Dr', 'Irith', 'AMAR-GUETTA', 'Dr', 'Anne-', 'Elise', 'DECAMBRON', 'Dr', 'Thierry', 'CORNU', 'Dr', 'Thibaut', 'NARDIN', 'Dr', 'Stéphane', 'ROMAND', 'Pharmacien', 'Biologiste', 'Pharmacien', 'Biologiste', 'Pharmacien', 'Biologiste', 'Médecin', 'Biologiste', 'Médecin', 'Biologiste']
# ['Dr', 'Mireille', 'BILLION-REY', 'Dr', 'Clotilde', 'GUERINEAU', 'Dr', 'Béatrice', 'OSER', 'Dr', 'Nancy', 'ROUX', 'Pharmacien', 'Biologiste', 'Pharmacien', 'Biologiste', 'Pharmacien', 'Biologiste', 'Pharmacien', 'Biologista']
# ['Ces', 'résultats', "d'analyses", 'médicales', 'sont', 'confidentiels.', 'Si', 'ce', 'document', 'fax', 'ne', 'vous', 'est', 'pas', 'destiné,', 'prière', 'de', 'le', 'détruire', 'et', 'de', 'contacter', 'le', 'laboratoire', 'au', '0153388899.']
# ['Cet', 'exemplaire', 'ne', 'constitue', 'pas', 'un', 'original', 'et', "n'est", 'pas', 'destiné', 'à', 'être', 'remis', 'au', 'patient', '(usage', 'interne', 'médical)']
# ['Compte-rendu', 'de', 'résultats', 'validé', 'par', 'un', 'biologiste']
# ['Compte', 'rendu', 'validé', 'par', ':ANNE', 'ELISE', 'DECAMBRON']
# ['Examens', 'du', ':', '02/12/20', 'prélevé', 'à', '17h52', 'Dossier', 'n°:', 'L120240152', 'prescrit', 'par:', 'FEILLET', 'MATHILDE', '(', 'IPSO', 'remplaçant)']
# ['Pour', ':', 'Mme', 'Leclercq', 'Jacqueline', 'né(e)', 'le', '29/08/1998', 'NNP', ':']
# ['MICROBIOLOGIE']
# ['RECHERCHE', "D'INFECTIONS", 'SEXUELLEMENT', 'TRANSMISSIBLES']
# ['Détection', 'par', 'PCR', 'multiplexe', 'Aliplex', 'STI', '(Seegene 0', 'Origine', ':', 'Endocol']
# ['Recherche', 'de', 'Chlamydia', 'trachomatis', ':', 'NEGATIVE', 'Recherche', 'de', 'Neisseria', 'gonorrheae', ':', 'NEGATIVE']
# ['Recherche', 'de', 'Trichomonas', 'vaginalis', ':', 'NEGATIVE']
# ['Compte-rendu', 'complet', 'de', 'résultats,', 'validé', 'par', 'ANNE', 'ELISE', 'DECAMBRON', '1/1']
# ['ANNE', 'ELISE', 'DECAMBRON']
# ['LE', 'LABO', 'REPUBLIQUE', '-', '2', 'BOULEVARD', 'DE', 'MAGENTA', '75010', 'PARIS']

# %% [markdown]
# # Récupérer le top des unités trouvées dans les documents

# %%
with open("utils/results/bioloinc_units.json", 'r') as fichier_json:
    units = json.load(fichier_json)

# %%
units
# Out:
# {'%  réactivité (avec DTT)': ['%'],
#  '%  réactivité (sans DTT)': ['%'],
#  '% CD10': ['%'],
#  '% CD16+CD56+': ['%'],
#  '% CD19+': ['%'],
#  '% CD3': ['%'],
#  '% CD3+CD4+CD8': ['%'],
#  '% CD3-CD16+CD56+': ['%'],
#  '% CD3-CD19+': ['%'],
#  '% CD4': ['%'],
#  '% CD45': ['%'],
#  '% CD5': ['%'],
#  '% CD8': ['%'],
#  "% d'hématies foetales": ['%', '%{RBCs}'],
#  "% d'hémoglobine foetale": ["% d'Hb", '%{Hb}'],
#  '% de réactivité IgG anti-HLA classe 1': ['%'],
#  '% de réactivité IgG anti-HLA classe 2': ['%'],
#  '1,25 dihydroxy vitamines D': ['pmol/L', 'pg/mL'],
#  '1-hydroxymidazolam': ['ng/mL'],
#  '1-méthylhistidine': ['µmol/L', 'umol/L'],
#  '1-méthylhistidine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '11-déoxycortisol': ['nmol/L', 'ng/mL'],
#  '11-déoxycortisol J01 après métopirone': ['nmol/L'],
#  '11-déoxycortisol avant métopirone': ['nmol/L'],
#  '17-hydroxyprogestérone': ['nmol/L', 'ng/mL'],
#  '17-hydroxyprogestérone salivaire': ['nmol/L'],
#  '17-hydroxyprégnénolone': ['nmol/L', 'ng/mL'],
#  '2-aminoadipate': ['µmol/L', 'umol/L'],
#  '2-aminoadipate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-aminobutyrate': ['µmol/L', 'umol/L'],
#  '2-aminobutyrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-aminoisobutyrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-cétoglutarate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-hydroxy-3-méthylvalérate/créatinine': ['µmol/mmol créat',
#   'umol/mmol{creat}'],
#  '2-hydroxyadipate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-hydroxybutyrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-hydroxyglutarate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-hydroxyisocaproate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-hydroxyisovalérate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-méthyl-3-hydroxybutyrate/créatinine': ['µmol/mmol créat',
#   'umol/mmol{creat}'],
#  '2-méthylcitrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-méthylsuccinate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-méthyltyrosine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-oxo-3-méthylvalérate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-oxoadipate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-oxoisocaproate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-oxoisovalérate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '2-éthyl,3-hydroxypropionate/créatinine': ['µmol/mmol créat',
#   'umol/mmol{creat}'],
#  '21-déoxycortisol': ['nmol/L', 'ng/mL'],
#  '3 méthoxy tyramine urinaire': ['nmol/L'],
#  '3 méthoxy tyramine urinaire /24h': ['nmol/L'],
#  '3 méthoxy tyramine urinaire/créatinine': ['nmol/L'],
#  '3-hydroxy-3-méthylglutarate/créatinine': ['µmol/mmol créat',
#   'umol/mmol{creat}'],
#  '3-hydroxyadipate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-hydroxyglutarate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-hydroxyisobutyrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-hydroxyisovalérate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-hydroxypropionate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-hydroxyvalérate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-méthylcrotonylglycine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-méthylglutaconate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-méthylglutarate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-méthylhistidine': ['µmol/L', 'umol/L'],
#  '3-méthylhistidine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-phényllactate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '3-phénylpyruvate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '4-hydroxymidazolam': ['ng/mL'],
#  '4-hydroxyphénylacétate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '4-hydroxyphényllactate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '4-hydroxyphénylpyruvate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  "5'-nucléotidase": ['UI/L', '[IU]/L'],
#  '5-fluorocytosine': ['mg/L'],
#  '5-fluorouracile': ['ng/mL'],
#  '5-hydroxyhexanoate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  '5HIAA': ['µmol/L', 'umol/L', 'mg/L'],
#  '5HIAA /24h': ['µmol/24H', 'umol/(24.h)', 'mg/24h', 'mg/(24.h)'],
#  '5HIAA/créatinine': ['µmol/mmol créat',
#   'umol/mmol{creat}',
#   'mg/mg créat',
#   'mg/mg{creat}'],
#  '6-monoacétylmorphine': ['ng/mL'],
#  '7-aminoclonazépam': ['µg/L', 'ug/L'],
#  '7-aminoflunitrazépam': ['ng/mL'],
#  '7-déhydrocholestérol': ['nmol/L'],
#  '9-hydroxyrispéridone': ['ng/mL'],
#  'ACC : TCA Patient': ['s'],
#  'ACC : Temps de reptilase Patient': ['s'],
#  'ACC : Test de neutralisation Patient': ['s'],
#  'ACE': ['ng/mL'],
#  'ACE - Liquide de ponction': ['ng/mL'],
#  'ACTH': ['pmol/L', 'pg/mL'],
#  'ACTH 12h': ['pmol/L'],
#  'ACTH 16h': ['pmol/L', 'pg/mL'],
#  'ACTH 20h': ['pmol/L'],
#  'ACTH 24h': ['pmol/L'],
#  'ACTH 4h': ['pmol/L'],
#  'ACTH 8h': ['pmol/L', 'pg/mL'],
#  'ADAMTS13': ['%'],
#  'AFP': ['UI/mL', '[IU]/mL', 'ng/mL'],
#  'AFP - liquide de ponction': ['ng/mL'],
#  'AFP LCR': ['µg/L', 'ug/L', 'UI/mL', '[IU]/mL'],
#  'AGTLC (C22:0)': ['mmol/L'],
#  'AGTLC (C22:1 n-9)': ['mmol/L'],
#  'AGTLC (C24:0)': ['mmol/L'],
#  'AGTLC (C26:0)': ['mmol/L'],
#  'AGTLC (C26:1)': ['mmol/L'],
#  'ALAT': ['UI/L', '[IU]/L'],
#  'AMH': ['pmol/L', 'ng/mL'],
#  'ASAT': ['UI/L', '[IU]/L'],
#  'Abacavir': ['ng/mL'],
#  'Abricot, f237': ['kU/L'],
#  'Absinthe, w5': ['kU/L'],
#  'Ac HBs': ['UI/L', '[IU]/L'],
#  'Ac HVA totaux': ['UI/L', '[IU]/L'],
#  'Ac Toxocara (LCR)': ['UA/mL', "[arb'U]/mL"],
#  'Ac VZV IgG': ['UI/L', '[IU]/L'],
#  'Ac virus de la rubéole': ['UI/mL', '[IU]/mL'],
#  'Acanthocytes %o': ['/10*3', '/10*3{RBCs}'],
#  'Acarus siro, d70': ['kU/L'],
#  'Aciclovir': ['mg/L'],
#  'Acide alpha-linolénique (C18:3 n-3)': ['mmol/L'],
#  'Acide arachidate (C20:0)': ['mmol/L'],
#  'Acide arachidonique (C20:4 n-6)': ['mmol/L'],
#  'Acide caprique (C10:0)': ['mmol/L'],
#  'Acide cis-11-eicosénoïque (C20:1 n-9)': ['mmol/L'],
#  'Acide cis-13-eicosénoïque (C20:1 n-7)': ['mmol/L'],
#  'Acide docosadiénoïque (C22:2 n-6)': ['mmol/L'],
#  'Acide docosahexaénoïque (C22:6 n-3)': ['mmol/L'],
#  'Acide docosanoïque (C22:1)': ['mmol/L'],
#  'Acide docosapentaénoïque (C22:5 n-3)': ['mmol/L'],
#  'Acide docosapentaénoïque (C22:5 n-6)': ['mmol/L'],
#  'Acide docosatétraénoïque (C22:4 n-6)': ['mmol/L'],
#  'Acide décènoïque (C10:1)': ['mmol/L'],
#  'Acide eicosadiénoïque (C20:2 n-6)': ['mmol/L'],
#  'Acide eicosapentaénoïque (C20:5 n-3)': ['mmol/L'],
#  'Acide gamma-linolénique (C18:3 n-6)': ['mmol/L'],
#  'Acide hexadécadiénoïque (C16:2)': ['mmol/L'],
#  'Acide hexadécènoïque (C16:1 n-9)': ['mmol/L'],
#  'Acide homogamma linolénique (C20:3 n-6)': ['mmol/L'],
#  'Acide hyaluronique': ['µg/L', 'ug/L'],
#  'Acide lactique': ['mmol/L'],
#  'Acide laurique (C12:0)': ['mmol/L'],
#  'Acide lauroléique (C12:1)': ['mmol/L'],
#  'Acide linoléique (C18:2 n-6)': ['mmol/L'],
#  'Acide myristique (C14:0)': ['mmol/L'],
#  'Acide myristoléique (C14:1)': ['mmol/L'],
#  'Acide nervonique (C24:1)': ['mmol/L'],
#  'Acide octadécatétraénoïque (C18:4 n-3)': ['mmol/L'],
#  'Acide octanoïque (C8:0)': ['mmol/L'],
#  'Acide oléique (C18:1 n-9)': ['mmol/L'],
#  'Acide palmitique (C16:0)': ['mmol/L'],
#  'Acide palmitoléique (C16:1 n-7)': ['mmol/L'],
#  'Acide phytanique (C16:0)': ['mmol/L'],
#  'Acide pristanique (C15:0)': ['mmol/L'],
#  'Acide pyruvique': ['µmol/L', 'umol/L'],
#  'Acide salicylique': ['mg/L'],
#  'Acide stéarique (C18:0)': ['mmol/L'],
#  'Acide tétradécadiènoïque (C14:2)': ['mmol/L'],
#  'Acide urique': ['µmol/L', 'umol/L', 'mg/L'],
#  'Acide urique urinaire': ['mmol/L', 'mg/L'],
#  'Acide urique urinaire /24h': ['mmol/24h',
#   'mmol/(24.h)',
#   'mg/24h',
#   'mg/(24.h)'],
#  'Acide vaccénique (C18:1 n-7)': ['mmol/L'],
#  'Acide valproïque': ['mg/L'],
#  'Acides aminés totaux - interprétation': ['µmol/L', 'umol/L'],
#  'Acides aminés/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Acides gras (C20:3 n-9)': ['mmol/L'],
#  'Acides gras libres': ['mmol/L'],
#  'Acides gras totaux': ['mmol/L'],
#  'Aconitate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Acébutolol': ['ng/mL'],
#  'Acétoacétate': ['µmol/L', 'umol/L'],
#  'Acétoacétate AJ': ['µmol/L', 'umol/L'],
#  'Acétoacétate PP': ['µmol/L', 'umol/L'],
#  'Acétoacétate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Acétylcarnitine': ['µmol/L', 'umol/L'],
#  'Acétyltyrosine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Adalimumab': ['µg/mL', 'ug/mL'],
#  'Adipate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Adrénaline': ['nmol/L', 'pg/mL'],
#  'Adrénaline /24h': ['nmol/24h', 'nmol/(24.h)', 'µg/24h', 'ug/(24.h)'],
#  'Adrénaline urinaire': ['nmol/L', 'µg/L', 'ug/L'],
#  'Adrénaline urinaire/créatinine': ['µg/g', 'ug/g{creat}'],
#  'Adrénaline/créatinine': ['nmol/mmol', 'nmol/L/mmol{creat}'],
#  'Adéfovir': ['ng/mL'],
#  'Adénovirus Ac': ['UA/mL', "[arb'U]/mL"],
#  'Ag HBs': ['UI/L', '[IU]/L'],
#  'Ag solubles Candida (LCR)': ['UA/mL', "[arb'U]/mL"],
#  'Age du patient': ['ans', 'a'],
#  'Agrostide, g9': ['kU/L'],
#  'Agrégation plaquettaire (ADP)': ['%'],
#  'Agrégation plaquettaire (Acide arachidonique)': ['%'],
#  'Agrégation plaquettaire (Collagène)': ['%'],
#  'Agrégation plaquettaire (Ristocétine)': ['%'],
#  'Aiglefin, f42': ['kU/L'],
#  'Ail, f47': ['kU/L'],
#  'Alanine': ['µmol/L', 'umol/L'],
#  'Alanine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Albumine': ['g/L', 'mg/L'],
#  'Albumine %': ['%'],
#  'Albumine LCR': ['mg/L'],
#  'Albumine sérique bovine, e204': ['kU/L'],
#  'Albumine urinaire': ['mg/L'],
#  'Albumine urinaire %': ['%'],
#  'Albumine urinaire /24h': ['mg/24h', 'mg/(24.h)'],
#  'Albumine urinaire/créatinine': ['mg/mmol créat', 'mg/mmol{creat}'],
#  'Alcoolémie': ['g/L'],
#  'Aldolase': ['U/L'],
#  'Aldostérone': ['pmol/L', 'pg/mL'],
#  'Aldostérone T1h synacthène': ['pmol/L', 'pg/mL'],
#  'Aldostérone T30min synacthène': ['pmol/L', 'pg/mL'],
#  'Aldostérone avant synacthène': ['pmol/L', 'pg/mL'],
#  'Aldostérone couchée': ['pmol/L', 'pg/mL'],
#  'Aldostérone debout': ['pmol/L', 'pg/mL'],
#  'Aldostérone urinaire': ['nmol/L', 'µg/L', 'ug/L', 'µg/24h', 'ug/(24.h)'],
#  'Aldostérone urinaire/24h': ['nmol/24h', 'nmol/(24.h)'],
#  'Alfentanyl': ['ng/mL'],
#  'Alimémazine': ['ng/mL'],
#  'Alloisoleucine': ['µmol/L', 'umol/L'],
#  'Alpha 1 antitrypsine': ['g/L'],
#  'Alpha 1 antitrypsine fécale': ['g/L'],
#  'Alpha 2 macroglobuline': ['g/L'],
#  'Alpha glucosidase': ['mU/mL'],
#  'Alpha-1 globulines': ['g/L', 'mg/L'],
#  'Alpha-1 globulines %': ['%'],
#  'Alpha-1-microglobuline urinaire': ['mg/L'],
#  'Alpha-1-microglobuline urinaire /24h': ['mg/24h', 'mg/(24.h)'],
#  'Alpha-1-microglobuline urinaire/créatinine': ['mg/mg créat', 'mg/mg{creat}'],
#  'Alpha-2 globulines': ['g/L', 'mg/L'],
#  'Alpha-2 globulines %': ['%'],
#  'Alpha-2-antiplasmine': ['%', 'U/mL', "[arb'U]/mL"],
#  'Alpha-amylase, k87': ['kU/L'],
#  'Alpha-lactalbumine, f76': ['kU/L'],
#  'Alpiste, g71': ['kU/L'],
#  'Alprazolam': ['ng/mL'],
#  'Alternaria alternata, m6': ['kU/L'],
#  'Alternaria alternata, rAlt a1': ['kU/L'],
#  'Aluminium': ['µmol/L', 'umol/L', 'µg/L', 'ug/L'],
#  'Aluminium urinaire': ['µmol/L', 'umol/L', 'µg/L', 'ug/L'],
#  'Aluminium urinaire/24h': ['µmol/24H', 'umol/(24.h)', 'µg/24h', 'ug/(24.h)'],
#  'Amande, f20': ['kU/L'],
#  'Amaranthe commune, w14': ['kU/L'],
#  'Amaranthe de Palmer, w82': ['kU/L'],
#  'Ambroisie trilobée, w3': ['kU/L'],
#  'Ambroisie w230,nAmba1': ['kU/L'],
#  'Ambroisie à épi grêle,  w2': ['kU/L'],
#  'Ambroisie élevée, w1': ['kU/L'],
#  'Amikacine': ['mg/L'],
#  'Amikacine - Pic': ['mg/L'],
#  'Amikacine - Taux résiduel': ['mg/L'],
#  'Amino bêta guanidinopropionate': ['µmol/L', 'umol/L'],
#  'Amino bêta guanidinopropionate/créatinine': ['µmol/mmol créat',
#   'umol/mmol{creat}'],
#  'Amitriptyline': ['ng/mL'],
#  'Ammoniaque': ['µmol/L', 'umol/L', 'mg/L', 'µg/L', 'ug/L'],
#  'Ammonium quaternaire AM4': ['kU/L'],
#  'Amoxapine': ['ng/mL'],
#  'Amoxicilline': ['mg/L'],
#  'Amoxicilline+clavulanate': ['mg/L'],
#  'Amoxicilline, c6': ['kU/L'],
#  'Amphotéricine B': ['mg/L'],
#  'Amphétamines': ['ng/mL'],
#  'Ampicilline, c5': ['kU/L'],
#  'Amprénavir': ['ng/mL'],
#  'Amylase': ['UI/L', '[IU]/L'],
#  'Amylasurie': ['U/L'],
#  'Amylasurie /24h': ['U/24h', 'U/(24.h)'],
#  'Ananas, f210': ['kU/L'],
#  'Anchois, f313': ['kU/L'],
#  'Androstanediol glucuronide': ['nmol/L'],
#  'Aneth, f277': ['kU/L'],
#  'Angiotensine II': ['pmol/L'],
#  'Anguille, f264': ['kU/L'],
#  'Anhydride phtalique, k79': ['kU/L'],
#  'Anhydride triméllitique, k86': ['kU/L'],
#  'Anidulafungine': ['mg/L'],
#  'Anis, f271': ['kU/L'],
#  'Anisakis, p4': ['kU/L'],
#  'Ansérine': ['µmol/L', 'umol/L'],
#  'Ansérine à balais, w17': ['kU/L'],
#  'Ansérine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Anti-ADN natif': ['UI/mL', '[IU]/mL', 'UI/L', '[IU]/L'],
#  'Anti-ADN natif IgG': ['UI/mL', '[IU]/mL'],
#  'Anti-ADN natif IgM': ['UI/mL', '[IU]/mL'],
#  'Anti-ARN polymérase III': ['U/mL', "[arb'U]/mL"],
#  'Anti-Actine F': ['U/mL', "[arb'U]/mL"],
#  'Anti-Adalimumab': ['ng/mL'],
#  'Anti-Annexine V IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-Annexine V IgM': ['U/mL', "[arb'U]/mL"],
#  'Anti-BP 180': ['U/mL', "[arb'U]/mL"],
#  'Anti-BP 230': ['U/mL', "[arb'U]/mL"],
#  'Anti-Bêta-2 glycoprotéine 1 IgA': ['U/mL', "[arb'U]/mL"],
#  'Anti-Bêta-2 glycoprotéine 1 IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-Bêta-2 glycoprotéine 1 IgM': ['U/mL', "[arb'U]/mL"],
#  'Anti-CCP': ['U/mL', "[arb'U]/mL"],
#  'Anti-CCP IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-Cardiolipine IgA': ['UAPL', "[APL'U]"],
#  'Anti-Cardiolipine IgG': ['UGPL', "[GPL'U]"],
#  'Anti-Cardiolipine IgM': ['UGPL', "[GPL'U]"],
#  'Anti-Cellules pariétales gastrique': ['U/mL', "[arb'U]/mL"],
#  'Anti-Centromère': ['U/mL', "[arb'U]/mL"],
#  'Anti-Centromère cenpB': ['U/mL', "[arb'U]/mL"],
#  'Anti-Certolizumab': ['ng/mL'],
#  'Anti-Desmogléine 1': ['U/mL', "[arb'U]/mL"],
#  'Anti-Desmogléine 3': ['U/mL', "[arb'U]/mL"],
#  'Anti-Etanercept': ['ng/mL'],
#  'Anti-Facteur intrinsèque': ['U/mL', "[arb'U]/mL"],
#  'Anti-GAD': ['UA/mL', "[arb'U]/mL"],
#  'Anti-Golimumab': ['ng/mL'],
#  'Anti-HMGCoA réductase': ['U/mL', "[arb'U]/mL"],
#  'Anti-Histones': ['U/mL', "[arb'U]/mL"],
#  'Anti-Histones IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-IA2': ['UA/mL', "[arb'U]/mL"],
#  'Anti-Infliximab': ['ng/mL'],
#  'Anti-Jo1': ['U/mL', "[arb'U]/mL"],
#  'Anti-MAG': ['U/mL', "[arb'U]/mL"],
#  'Anti-MPO': ['U/mL', "[arb'U]/mL"],
#  'Anti-MPO IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-Mi2': ['U/mL', "[arb'U]/mL"],
#  'Anti-PCNA': ['U/mL', "[arb'U]/mL"],
#  'Anti-PR3': ['U/mL', "[arb'U]/mL"],
#  'Anti-PR3 IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-PS/PT IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-PS/PT IgM': ['U/mL', "[arb'U]/mL"],
#  'Anti-Phosphatidyléthanolamine IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-Phosphatidyléthanolamine IgM': ['U/mL', "[arb'U]/mL"],
#  'Anti-RACH': ['nmol/L'],
#  'Anti-RNP': ['U/mL', "[arb'U]/mL"],
#  'Anti-Rituximab': ['ng/mL'],
#  'Anti-Ro 52kd': ['U/mL', "[arb'U]/mL"],
#  'Anti-Ro 60kd': ['U/mL', "[arb'U]/mL"],
#  'Anti-Récepteur à la TSH (TRAK)': ['U/L', 'UI/L', '[IU]/L'],
#  'Anti-SSA': ['U/mL', "[arb'U]/mL"],
#  'Anti-SSB': ['U/mL', "[arb'U]/mL"],
#  'Anti-Saccharomyces cerevisiae': ['UA/mL', "[arb'U]/mL"],
#  'Anti-Saccharomyces cerevisiae IgG': ['UA/mL', "[arb'U]/mL"],
#  'Anti-Scl70': ['U/mL', "[arb'U]/mL"],
#  'Anti-Sm': ['U/mL', "[arb'U]/mL"],
#  'Anti-Sm-RNP': ['U/mL', "[arb'U]/mL"],
#  'Anti-Thyroglobuline': ['UI/mL', '[IU]/mL'],
#  'Anti-Thyropéroxidase': ['UI/mL', '[IU]/mL'],
#  'Anti-U1 RNP nucléaire': ['UI/L', '[IU]/L'],
#  'Anti-Ustekinumab': ['ng/mL'],
#  'Anti-Védolizumab': ['ng/mL'],
#  'Anti-ZnT8': ['UA/mL', "[arb'U]/mL"],
#  'Anti-canaux calciques': ['mmol/L'],
#  'Anti-ganglioside GD1a IgG': ['UA/mL', "[arb'U]/mL"],
#  'Anti-ganglioside GD1a IgM': ['UA/mL', "[arb'U]/mL"],
#  'Anti-ganglioside GM1 IgG+IgM': ['UA/mL', "[arb'U]/mL"],
#  'Anti-insuline': ['U/mL', "[arb'U]/mL"],
#  'Anti-membrane basale glomérulaire': ['U/mL', "[arb'U]/mL"],
#  'Anti-nucléosome': ['UA', "[arb'U]"],
#  'Anti-phospholipides IgG': ['U/mL', "[arb'U]/mL"],
#  'Anti-phospholipides IgM': ['U/mL', "[arb'U]/mL"],
#  'Anti-ribosome P': ['U/mL', "[arb'U]/mL"],
#  'Antigène CFP 10': ['SFC/Puits', '[CFU]'],
#  'Antigène ESAT 6': ['SFC/Puits', '[CFU]'],
#  'Antigène Facteur II': ['%', 'U/mL', "[arb'U]/mL"],
#  'Antigène Facteur IX': ['%', 'U/mL', "[arb'U]/mL"],
#  'Antigène Facteur V': ['%', 'U/mL', "% [arb'U]/mL"],
#  'Antigène Facteur VII': ['%'],
#  'Antigène Facteur VIII': ['%', 'U/mL', "[arb'U]/mL"],
#  'Antigène Facteur X': ['%', 'U/mL', "[arb'U]/mL"],
#  'Antigène Facteur XI': ['%', 'U/mL', "[arb'U]/mL"],
#  'Antigène Facteur XII': ['%', 'U/mL', "[arb'U]/mL"],
#  'Antigène Facteur XIII': ['mg/L'],
#  'Antigène Facteur willebrand': ['%'],
#  'Antimoine': ['nmol/L', 'µg/L', 'ug/L'],
#  'Antistreptodornase': ['UI/mL', '[IU]/mL'],
#  'Antistreptolysine O': ['UI/mL', '[IU]/mL'],
#  'Antithrombine': ['%'],
#  'Antithrombine antigène': ['%'],
#  'Antitoxine tétanique IgG': ['UI/mL', '[IU]/mL'],
#  'Apixaban (Anti-Xa)': ['ng/mL'],
#  'Apolipoprotéine AI': ['g/L'],
#  'Apolipoprotéine B': ['g/L'],
#  'Arachide, f13': ['kU/L'],
#  'Arachide, rAra h1': ['kU/L'],
#  'Arachide, rAra h2': ['kU/L'],
#  'Arachide, rAra h3': ['kU/L'],
#  'Arachide, rAra h6': ['kU/L'],
#  'Arachide, rAra h8': ['kU/L'],
#  'Arachide, rAra h9': ['kU/L'],
#  'Arginine': ['µmol/L', 'umol/L'],
#  'Arginine urinaire': ['µmol/L', 'umol/L'],
#  'Arginine urinaire /24h': ['µmol/24H', 'umol/(24.h)'],
#  'Arginine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Argininosuccinate': ['µmol/L', 'umol/L'],
#  'Argininosuccinate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Armoise commune, nArt v1': ['kU/L'],
#  'Armoise commune, nArt v3': ['kU/L'],
#  'Armoise commune, w6': ['kU/L'],
#  'Arroche, w15': ['kU/L'],
#  'Arsenic': ['nmol/L', 'µg/L', 'ug/L'],
#  'Ascaris, p1': ['kU/L'],
#  'Asparagine': ['µmol/L', 'umol/L'],
#  'Asparagine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Aspartate': ['µmol/L', 'umol/L'],
#  'Aspartate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Aspartylglycosamine': ['µmol/L', 'umol/L'],
#  'Asperge, f261': ['kU/L'],
#  'Aspergillus flavus, m228': ['kU/L'],
#  'Aspergillus fumigatus, m3': ['kU/L'],
#  'Aspergillus fumigatus, rAspf1': ['kU/L'],
#  'Aspergillus fumigatus, rAspf2': ['kU/L'],
#  'Aspergillus fumigatus, rAspf3': ['kU/L'],
#  'Aspergillus fumigatus, rAspf4': ['kU/L'],
#  'Aspergillus fumigatus, rAspf6': ['kU/L'],
#  'Aspergillus niger, m207': ['kU/L'],
#  'Aspergillus terreus, m36': ['kU/L'],
#  'Atazanavir': ['ng/mL'],
#  'Atovaquone': ['mg/L'],
#  'Aubergine, f262': ['kU/L'],
#  'Aulne t2': ['kU/L'],
#  'Aureobasidium pullulans, m12': ['kU/L'],
#  'Autre hémoglobine %': ["% d'Hb", '%{Hb}'],
#  'Autres cellules': ['%'],
#  'Autres cellules %': ['%'],
#  'Avocat, f96': ['kU/L'],
#  'Avoine cultivée, g14': ['kU/L'],
#  'Avoine, f7': ['kU/L'],
#  'Azélate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'BNP': ['pg/mL'],
#  'BNP après dialyse': ['pg/mL'],
#  'Balance ionique': ['mmol/L'],
#  'Banane, f92': ['kU/L'],
#  'Base excès': ['mmol/L'],
#  'Basilic, f269': ['kU/L'],
#  'Benzoate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Benzoylecgonine': ['ng/mL'],
#  'Betterave sucrière (graine), f227': ['kU/L'],
#  'Betterave sucrière, w210': ['kU/L'],
#  'Betterave, f319': ['kU/L'],
#  'Bicarbonate': ['mmol/L'],
#  'Bicarbonate après dialyse': ['mmol/L'],
#  'Bicarbonate artériel': ['mmol/L'],
#  'Bicarbonate capillaire': ['mmol/L'],
#  'Bicarbonate standard artériel': ['mmol/L'],
#  'Bicarbonate standard capillaire': ['mmol/L'],
#  'Bicarbonate standard veineux': ['mmol/L'],
#  'Bicarbonate veineux': ['mmol/L'],
#  'Bicarbonates': ['mmol/L'],
#  'Big-Big Prolactine': ['mUI/L', 'm[IU]/L'],
#  'Big-Big Prolactine %': ['%'],
#  'Bilirubine': ['µmol/L', 'umol/L', 'mg/L'],
#  'Bilirubine conjuguée': ['µmol/L', 'umol/L', 'mg/L'],
#  'Bilirubine libre': ['µmol/L', 'umol/L', 'mg/L'],
#  'Bilirubine urinaire': ['mg/L'],
#  "Blanc d'œuf, f1": ['kU/L'],
#  'Blastes': ['10*9/L', '%'],
#  'Blastes %': ['%'],
#  'Blatte américaine, i206': ['kU/L'],
#  'Blatte germanique, i6': ['kU/L'],
#  'Blatte orientale, i207': ['kU/L'],
#  'Bloc Bêta-Gamma': ['g/L'],
#  'Bloc Bêta-Gamma %': ['%'],
#  'Blomia tropicalis, d201': ['kU/L'],
#  'Blé (pollen), g15': ['kU/L'],
#  'Blé, f4': ['kU/L'],
#  'Blé, rTri a14': ['kU/L'],
#  'Blé, rTri a19': ['kU/L'],
#  'Boeuf, f27': ['kU/L'],
#  'Bore': ['µmol/L', 'umol/L', 'µg/L', 'ug/L'],
#  'Borrelia burgdorferi IgG': ['UA/mL', "[arb'U]/mL"],
#  'Borrelia burgdorferi IgM': ['UA/mL', "[arb'U]/mL"],
#  'Botrytis cinerea, m7': ['kU/L'],
#  'Bouleau, rBet v1': ['kU/L'],
#  'Bouleau, rBet v2': ['kU/L'],
#  'Bouleau, rBet v2 + rBetv4': ['kU/L'],
#  'Bouleau, rBet v4': ['kU/L'],
#  'Bouleau, rBet v6': ['kU/L'],
#  'Bouleau, t3': ['kU/L'],
#  'Brocoli, f260': ['kU/L'],
#  'Bromazépam': ['ng/mL'],
#  'Brome, g11': ['kU/L'],
#  'Broméline (MUXF3 CDD), o214': ['kU/L'],
#  'Broméline, k202': ['kU/L'],
#  'Bupivacaïne': ['ng/mL'],
#  'Buprénorphine': ['ng/mL'],
#  'Busulfan': ['ng/mL'],
#  'Bédaquiline': ['mg/L'],
#  'Béryllium': ['nmol/L', 'µg/L', 'ug/L'],
#  'Bêta 2 microglobuline': ['mg/L'],
#  'Bêta 2 microglobuline après dialyse': ['mg/L'],
#  'Bêta 2 microglobuline urinaire': ['mg/L'],
#  'Bêta 2 microglobuline urinaire /24h': ['mg/24h', 'mg/(24.h)'],
#  'Bêta 2 microglobuline urinaire/créatinine': ['mg/mg créat', 'mg/mg{creat}'],
#  'Bêta alanine': ['µmol/L', 'umol/L'],
#  'Bêta alanine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Bêta aminoisobutyrate': ['µmol/L', 'umol/L'],
#  'Bêta aminoisobutyrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Bêta globulines': ['g/L', 'mg/L'],
#  'Bêta globulines %': ['%'],
#  'Bêta hydroxybutyrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Bêta-1 globulines': ['g/L', 'mg/L'],
#  'Bêta-1 globulines %': ['%'],
#  'Bêta-2 globulines': ['g/L', 'mg/L'],
#  'Bêta-2 globulines %': ['%'],
#  'Bêta-hCG': ['UI/L', '[IU]/L'],
#  'Bêta-hCG libre': ['UI/L', '[IU]/L', 'ng/mL'],
#  'Bêta-lactoglobuline, f77': ['kU/L'],
#  'CA 19.9': ['U/mL', "[arb'U]/mL"],
#  'CBG': ['mg/L'],
#  'CCMH': ['g/dL'],
#  'CD10': ['/µL', '/uL'],
#  'CD16+CD56+': ['/µL', '/uL'],
#  'CD19+': ['/µL', '/uL'],
#  'CD3': ['/µL', '/uL'],
#  'CD3-CD16+CD56+': ['/µL', '/uL'],
#  'CD3-CD19+': ['/µL', '/uL'],
#  'CD4': ['/µL', '/uL'],
#  'CD4/CD8': ['%'],
#  'CD45': ['/µL', '/uL'],
#  'CD5': ['/µL', '/uL'],
#  'CD8': ['/µL', '/uL'],
#  'CDT (transferrine désialylée)': ['mg/L', '%'],
#  "CMV : Pourcentage d'avidité": ['%'],
#  'CO2 Total': ['mmol/L'],
#  'CO2 Total artériel': ['mmol/L'],
#  'CO2 Total veineux': ['mmol/L'],
#  'CO2 total après dialyse': ['mmol/L'],
#  'CRP': ['mg/L'],
#  'CRPus': ['mg/L'],
#  'Ca 125': ['U/mL', "[arb'U]/mL"],
#  'Ca 125 - Liquide de ponction': ['U/mL', "[arb'U]/mL"],
#  'Ca 15.3': ['U/mL', "[arb'U]/mL"],
#  'Ca 15.3 - Liquide de ponction': ['U/mL', "[arb'U]/mL"],
#  'Ca 19.9 - Liquide de ponction': ['U/mL', "[arb'U]/mL"],
#  'Ca 50': ['kU/L'],
#  'Ca 72-4': ['kU/L'],
#  'Cacao, f93': ['kU/L'],
#  'Cadmium': ['nmol/L', 'µg/L', 'ug/L'],
#  'Café (grain), f221': ['kU/L'],
#  'Café verts (grain), k70': ['kU/L'],
#  'Caféine': ['mg/L'],
#  'Calamar du pacifique, f58': ['kU/L'],
#  'Calamar, f258': ['kU/L'],
#  'Calcitonine': ['ng/L'],
#  'Calcium': ['mmol/L', 'mg/L'],
#  'Calcium après dialyse': ['mmol/L', 'mg/L'],
#  'Calcium corrigé': ['mmol/L', 'mg/L'],
#  'Calcium ionisé': ['mmol/L'],
#  'Calcium ionisé après filtration': ['mmol/L'],
#  'Calcium ionisé artériel': ['mg/L', 'mmol/L'],
#  'Calcium ionisé veineux': ['mmol/L'],
#  'Calcium urinaire': ['mmol/L', 'mg/L'],
#  'Calcium urinaire /24h': ['mmol/24h', 'mmol/(24.h)', 'mg/24h', 'mg/(24.h)'],
#  'Calcium/créatinine Ur': ['mmol/mmol',
#   'mmol/mmol{creat}',
#   'mg/mg créat',
#   'mg/mg{creat}'],
#  'Calprotectine fécale': ['µg/g', 'ug/g'],
#  'Camomille, w206': ['kU/L'],
#  'Canard (plumes), e86': ['kU/L'],
#  'Canari (déjections), e200': ['kU/L'],
#  'Candida - Ag solubles': ['pg/mL'],
#  'Candida albicans, m5': ['kU/L'],
#  'Cannabis': ['ng/mL'],
#  'Canne à sucre (pollen) g900': ['kU/L'],
#  'Canri (plumes), e201': ['kU/L'],
#  'Capacité de fixation de la transferrine': ['µmol/L', 'umol/L', 'mg/L'],
#  'Carambole, f295': ['kU/L'],
#  'Carbamazépine': ['mg/L'],
#  'Carboxyhémoglobine': ["% d'Hb", '%{Hb}'],
#  'Carboxyhémoglobine artérielle': ["% d'Hb", '%{Hb}'],
#  'Carboxyhémoglobine capillaire': ["% d'Hb", '%{Hb}'],
#  'Carboxyhémoglobine veineuse': ["% d'Hb", '%{Hb}'],
#  'Cardamone, f267': ['kU/L'],
#  'Carnitine': ['µmol/L', 'umol/L'],
#  'Carnosine': ['µmol/L', 'umol/L'],
#  'Carnosine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Carotte, f31': ['kU/L'],
#  'Caroube, f296': ['kU/L'],
#  'Carpe, rCyp c1': ['kU/L'],
#  'Carrelet, f254': ['kU/L'],
#  'Caspofungine': ['mg/L'],
#  'Caséine, f78': ['kU/L'],
#  'Catécholamines urinaires': ['nmol/L', 'µg/L', 'ug/L'],
#  'Catécholamines urinaires /24h': ['nmol/24h',
#   'nmol/(24.h)',
#   'µg/24h',
#   'ug/(24.h)'],
#  'Catécholamines urinaires/créatinine': ['nmol/mmol'],
#  'Cellules': ['/µL', '/uL'],
#  'Cellules atypiques': ['%'],
#  'Cellules de sézary': ['10*9/L'],
#  'Cellules de sézary %': ['%'],
#  'Cellules lymphomateuses': ['10*9/L'],
#  'Cellules lymphomateuses %': ['%'],
#  'Cellules malignes': ['%'],
#  'Cellules mononucléées': ['%'],
#  'Cellules mésothéliales': ['10*9/L'],
#  'Cellules mésothéliales %': ['%'],
#  'Cellules rondes': ['/mL'],
#  'Cellules épithéliales': ['%'],
#  'Cephalosporium acremonium, m202': ['kU/L'],
#  'Cerf, e216': ['kU/L'],
#  'Cerise, f242': ['kU/L'],
#  'Certolizumab': ['µg/mL', 'ug/mL'],
#  'Chaetomium globosum, m208': ['kU/L'],
#  'Champignon, f212': ['kU/L'],
#  'Charge virale CMV': ['UI/mL', '[IU]/mL', 'Copies/mL', '{copies}/mL'],
#  'Charge virale CMV (LCR)': ['Copies/mL', '{copies}/mL', 'UI/mL', '[IU]/mL'],
#  'Charge virale CMV (Moelle osseuse)': ['Copies/mL', '{copies}/mL'],
#  'Charge virale CMV (liquide amniotique)': ['Copies/mL', '{copies}/mL'],
#  'Charge virale CMV (liquide amniotique)(log)': ['log copies/mL',
#   '{Log_copies}/mL'],
#  'Charge virale CMV (log)': ['log UI/mL',
#   '{Log_IU}/mL',
#   'log copies/mL',
#   '{Log_copies}/mL'],
#  'Charge virale CMV (log) (LCR)': ['log copies/mL',
#   '{Log_copies}/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale EBV': ['Copies/mL', '{copies}/mL', 'UI/mL', '[IU]/mL'],
#  'Charge virale EBV (log)': ['log copies/mL',
#   '{Log_copies}/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale EBV dans le LCR': ['Copies/mL',
#   '{copies}/mL',
#   'UI/mL',
#   '[IU]/mL'],
#  'Charge virale EBV dans le LCR (log)': ['log copies/mL',
#   '{Log_copies}/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale EBV dans les urines': ['Copies/mL', '{copies}/mL'],
#  'Charge virale EBV dans les urines (log)': ['log copies/mL',
#   '{Log_copies}/mL'],
#  'Charge virale HHV-6': ['Copies/mL', '{copies}/mL'],
#  'Charge virale HHV-6 (log)': ['log copies/mL', '{Log_copies}/mL'],
#  'Charge virale HHV-8': ['Copies/mL',
#   '{copies}/mL',
#   'UI/mL',
#   '[IU]/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale HHV-8 (log)': ['log copies/mL', '{Log_copies}/mL'],
#  "Charge virale de l'EBV": ['UI/mL', '[IU]/mL'],
#  "Charge virale de l'EBV (log)": ['log UI/mL', '{Log_IU}/mL'],
#  "Charge virale de l'adénovirus": ['Copies/mL',
#   '{copies}/mL',
#   'UI/mL',
#   '[IU]/mL'],
#  "Charge virale de l'adénovirus (log)": ['log copies/mL',
#   '{Log_copies}/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale du CMV': ['UI/mL', '[IU]/mL'],
#  'Charge virale du CMV (log)': ['log UI/mL', '{Log_IU}/mL'],
#  'Charge virale du Parvovirus B19': ['Copies/mL',
#   '{copies}/mL',
#   'UI/mL',
#   '[IU]/mL'],
#  'Charge virale du Parvovirus B19 (log)': ['log copies/mL',
#   '{Log_copies}/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale du virus JC': ['Copies/mL',
#   '{copies}/mL',
#   'log copies/mL',
#   '{Log_copies}/mL'],
#  'Charge virale du virus VIH-1': ['Copies/mL',
#   '{copies}/mL',
#   'UI/mL',
#   '[IU]/mL'],
#  'Charge virale du virus VIH-1 (log)': ['log copies/mL',
#   '{Log_copies}/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale du virus VIH-1 (log) dans le LCR': ['log copies/mL',
#   '{Log_copies}/mL'],
#  'Charge virale du virus VIH-1 dans le LCR': ['Copies/mL', '{copies}/mL'],
#  'Charge virale du virus VIH-2': ['Copies/mL',
#   '{copies}/mL',
#   'UI/mL',
#   '[IU]/mL'],
#  'Charge virale du virus VIH-2 (log)': ['log copies/mL',
#   '{Log_copies}/mL',
#   'log UI/mL',
#   '{Log_IU}/mL'],
#  'Charge virale du virus VIH-2 (log) dans le LCR': ['log copies/mL',
#   '{Log_copies}/mL'],
#  'Charge virale du virus VIH-2 dans le LCR': ['Copies/mL', '{copies}/mL'],
#  'Charge virale du virus Zika': ['Copies/mL', '{copies}/mL'],
#  'Charge virale du virus Zika (log)': ['log copies/mL', '{Log_copies}/mL'],
#  'Charge virale du virus chikungunya': ['Copies/mL',
#   '{copies}/mL',
#   'log copies/mL',
#   '{Log_copies}/mL'],
#  "Charge virale du virus de l'hépatite B": ['UI/mL',
#   '[IU]/mL',
#   'Copies/mL',
#   '{copies}/mL'],
#  "Charge virale du virus de l'hépatite B (log)": ['log UI/mL',
#   '{Log_IU}/mL',
#   'log copies/mL',
#   '{Log_copies}/mL'],
#  "Charge virale du virus de l'hépatite C": ['UI/mL',
#   '[IU]/mL',
#   'Copies/mL',
#   '{copies}/mL'],
#  "Charge virale du virus de l'hépatite C (log copies)": ['log copies/mL',
#   '{Log_copies}/mL'],
#  "Charge virale du virus de l'hépatite C (log)": ['log UI/mL', '{Log_IU}/mL'],
#  "Charge virale du virus de l'hépatite D": ['UI/mL',
#   '[IU]/mL',
#   'Copies/mL',
#   '{copies}/mL'],
#  "Charge virale du virus de l'hépatite D (log)": ['log UI/mL', '{Log_IU}/mL'],
#  "Charge virale du virus de l'hépatite E": ['UI/mL', '[IU]/mL'],
#  "Charge virale du virus de l'hépatite E (log)": ['log UI/mL', '{Log_IU}/mL'],
#  'Charge virale du virus de la Varicelle (VZV)': ['Copies/mL', '{copies}/mL'],
#  'Charge virale virus BK': ['UI/mL', '[IU]/mL', 'Copies/mL', '{copies}/mL'],
#  'Charge virale virus BK (log)': ['log UI/mL',
#   '{Log_IU}/mL',
#   'log copies/mL',
#   '{Log_copies}/mL'],
#  'Charme, t209': ['kU/L'],
#  'Chat, e1': ['kU/L'],
#  'Chat, rFel d1': ['kU/L'],
#  'Chat, rFel d2': ['kU/L'],
#  'Chat, rFel d4': ['kU/L'],
#  'Chaînes Kappa libres': ['mg/L'],
#  'Chaînes Lambda libres': ['mg/L'],
#  'Cheval (viande) f321': ['kU/L'],
#  'Cheval, e205': ['kU/L'],
#  'Cheval, e3': ['kU/L'],
#  'Cheval, rEquc1': ['kU/L'],
#  'Chien, e2': ['kU/L'],
#  'Chien, e5': ['kU/L'],
#  'Chien, rCan f1': ['kU/L'],
#  'Chien, rCan f2': ['kU/L'],
#  'Chien, rCan f3': ['kU/L'],
#  'Chien, rCan f5': ['kU/L'],
#  'Chiendent digité g2': ['kU/L'],
#  'Chiendent digité, nCynd1': ['kU/L'],
#  'Chinchard, f60': ['kU/L'],
#  'Chinchilla, e208': ['kU/L'],
#  'Chlamydia pneumoniae IgA': ['UA/mL', "[arb'U]/mL"],
#  'Chlamydia pneumoniae IgG': ['UA/mL', "[arb'U]/mL"],
#  'Chlamydia trachomatis IgA': ['UA/mL', "[arb'U]/mL"],
#  'Chlamydia trachomatis IgG': ['UA/mL', "[arb'U]/mL"],
#  'Chlamydia trachomatis IgM': ['UA/mL', "[arb'U]/mL"],
#  'Chloramine T, k85': ['kU/L'],
#  'Chlordiazépoxide': ['ng/mL'],
#  'Chlore': ['mmol/L'],
#  'Chlore après dialyse': ['mmol/L'],
#  'Chlore urinaire': ['mmol/L'],
#  'Chlore urinaire /24h': ['mmol/24h', 'mmol/(24.h)'],
#  'Chlorhexidine, c8': ['kU/L'],
#  'Chloroquine': ['µg/L', 'ug/L'],
#  'Chlorpromazine': ['ng/mL'],
#  'Cholestérol': ['mmol/L', 'g/L'],
#  'Cholestérol HDL': ['mmol/L', 'g/L'],
#  'Cholestérol LDL': ['mmol/L', 'g/L'],
#  'Cholinestérases': ['UI/L', '[IU]/L'],
#  'Chou de bruxelles, f217': ['kU/L'],
#  'Chou, f216': ['kU/L'],
#  'Chou-fleur, f291': ['kU/L'],
#  'Chrome': ['nmol/L', 'µg/L', 'ug/L'],
#  'Chromogranine A': ['µg/L', 'ug/L'],
#  'Chymopapaïne, c209': ['kU/L'],
#  'Châtaigne, f299': ['kU/L'],
#  'Châtaignier, t206': ['kU/L'],
#  'Chèvre, e80': ['kU/L'],
#  'Chénopode blanc, w10': ['kU/L'],
#  'Chêne, t7': ['kU/L'],
#  'Ciclosporine T2h': ['µg/L', 'ug/L'],
#  'Ciclosporine taux résiduel': ['µg/L', 'ug/L'],
#  'Ciprofloxacine': ['mg/L'],
#  'Cirier, t56': ['kU/L'],
#  'Cisplatine': ['ng/mL'],
#  'Citalopram': ['ng/mL'],
#  'Citrate': ['mmol/L'],
#  'Citrate urinaire': ['µmol/L', 'umol/L'],
#  'Citrate urinaire /24h': ['µmol/24H', 'umol/(24.h)'],
#  'Citrate urinaire/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Citron vert, f306': ['kU/L'],
#  'Citron, f208': ['kU/L'],
#  'Citrouille (graine), f226': ['kU/L'],
#  'Citrouille, f225': ['kU/L'],
#  'Citrulline': ['µmol/L', 'umol/L'],
#  'Citrulline urinaire': ['µmol/L', 'umol/L'],
#  'Citrulline urinaire /24h': ['µmol/24H', 'umol/(24.h)'],
#  'Citrulline/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Cladosporium herbarum, m2': ['kU/L'],
#  'Clairance des phosphates': ['mL/min'],
#  'Clairance à la créatinine': ['mL/min'],
#  'Clairance à la créatinine  de Cockroft': ['mL/min'],
#  'Clairance à la créatinine corrigée': ['mL/min/1,73m²', 'mL/min/{1.73_m2}'],
#  'Clarithromycine': ['mg/L'],
#  'Clindamycine': ['mg/L'],
#  'Clobazam': ['ng/mL'],
#  'Clomipramine': ['ng/mL'],
#  'Clonazépam': ['µg/L', 'ug/L'],
#  'Clorazépate': ['ng/mL'],
#  'Clou de girofle, f268': ['kU/L'],
#  'Cloxacilline': ['mg/L'],
#  'Clozapine': ['ng/mL'],
#  'Co2 Total': ['mmol/L'],
#  'Cobalt': ['nmol/L', 'µg/L', 'ug/L'],
#  'Cobaye, e6': ['kU/L'],
#  'Cocaéthylène': ['ng/mL'],
#  'Cocaïne': ['ng/mL'],
#  'Codéine': ['ng/mL'],
#  'Coefficient de saturation': ['%'],
#  'Colistine': ['mg/L'],
#  'Colza (graine), f316': ['kU/L'],
#  'Colza, w203': ['kU/L'],
#  'Complexe plasmine-antiplasmine': ['µg/mL', 'ug/mL'],
#  'Complément C1 estérase inhibiteur': ['g/L'],
#  'Complément C1 estérase inhibiteur (%)': ['%'],
#  'Complément C1q': ['g/L'],
#  'Complément C3': ['g/L'],
#  'Complément C4': ['g/L'],
#  'Complément total': ['U/mL', "[arb'U]/mL"],
#  'Conalbumine, f323': ['kU/L'],
#  'Concombre, f244': ['kU/L'],
#  'Contrôle négatif': ['U/mL', "[arb'U]/mL", 'SFC/Puits', '[CFU]'],
#  'Contrôle positif': ['U/mL', "[arb'U]/mL", 'SFC/Puits', '[CFU]'],
#  'Coproporphyrine': ['nmol/L'],
#  'Coproporphyrine %': ['%'],
#  'Coproporphyrine /24h': ['nmol/24h', 'nmol/(24.h)'],
#  'Coproporphyrine 1 %': ['%'],
#  'Coproporphyrine/créatinine': ['nmol/mmol'],
#  'Coquille saint jacque, f338': ['kU/L'],
#  'Coriandre, f317': ['kU/L'],
#  'Corps cétoniques urinaires': ['mg/L'],
#  'Corticostérone': ['nmol/L', 'µg/L', 'ug/L'],
#  'Cortisol': ['nmol/L', 'ng/mL'],
#  'Cortisol 12h': ['nmol/L', 'ng/mL'],
#  'Cortisol 16h': ['nmol/L', 'ng/mL'],
#  'Cortisol 20h': ['nmol/L', 'ng/mL'],
#  'Cortisol 24h': ['nmol/L', 'ng/mL'],
#  'Cortisol 4h': ['nmol/L', 'ng/mL'],
#  'Cortisol 8h': ['nmol/L', 'ng/mL'],
#  'Cortisol T1h synacthène': ['nmol/L', 'ng/mL'],
#  'Cortisol T30min synacthène': ['nmol/L', 'ng/mL'],
#  'Cortisol après freinage': ['nmol/L', 'ng/mL'],
#  'Cortisol avant synacthène': ['nmol/L', 'ng/mL'],
#  'Cortisol libre': ['nmol/L', 'µg/L', 'ug/L'],
#  'Cortisol libre /24h': ['nmol/24h', 'nmol/(24.h)', 'µg/24h', 'ug/(24.h)'],
#  'Cortisol salivaire': ['nmol/L'],
#  'Cortisol salivaire 16h': ['nmol/L', 'µg/L', 'ug/L'],
#  'Cortisol salivaire 8h': ['nmol/L', 'µg/L', 'ug/L'],
#  'Cortisone': ['nmol/L', 'µg/L', 'ug/L'],
#  'Cortisone urinaire': ['µmol/L', 'umol/L'],
#  'Cortisone urinaire /24h': ['µmol/24H', 'umol/(24.h)'],
#  'Cotinine': ['mg/L'],
#  'Cotinine urinaire': ['mg/L'],
#  'Coton, k83': ['kU/L'],
#  'Courgette, f118': ['kU/L'],
#  'Crabe, f23': ['kU/L'],
#  'Crevette grise (tropomyosine), rPen a1': ['kU/L'],
#  'Crevette, f24': ['kU/L'],
#  'Crosslaps': ['ng/mL', 'pmol/L'],
#  'Crosslaps urinaire': ['µg/L', 'ug/L'],
#  'Crosslaps urinaire /24h': ['µg/24h', 'ug/(24.h)'],
#  'Crosslaps urinaire/créatinine': ['µg/mmol', 'ug/mmol{creat}'],
#  'Cryoglobulines IgA': ['mg/L'],
#  'Cryoglobulines IgG': ['mg/L'],
#  'Cryoglobulines IgM': ['mg/L'],
#  'Créatine kinase (CK)': ['UI/L', '[IU]/L'],
#  'Créatine kinase MB (CKMB)': ['UI/L', '[IU]/L'],
#  'Créatinine': ['µmol/L', 'umol/L', 'mg/L'],
#  'Créatinine - Liquide de ponction': ['µmol/L', 'umol/L'],
#  'Créatinine après dialyse': ['µmol/L', 'umol/L', 'mg/L'],
#  'Créatinine urinaire': ['mmol/L', 'mg/L'],
#  'Créatinine urinaire /24h': ['mmol/24h',
#   'mmol/(24.h)',
#   'mg/24h',
#   'mg/(24.h)'],
#  'Cuivre': ['µmol/L', 'umol/L', 'µg/L', 'ug/L'],
#  'Cuivre urinaire': ['µmol/L', 'umol/L'],
#  'Cuivre urinaire /24h': ['µmol/24H', 'umol/(24.h)'],
#  'Cumin, f265': ['kU/L'],
#  'Curry, f281': ['kU/L'],
#  'Curvularia lunata, m16': ['kU/L'],
#  'Cyclophosphamide': ['mg/L'],
#  'Cyclosérine': ['mg/L'],
#  'Cyfra 21': ['µg/L', 'ug/L'],
#  'Cylindres': ['/mL'],
#  'Cynorrhodon, f330': ['kU/L'],
#  'Cyprès, nCup a1': ['kU/L'],
#  'Cyprès, t23': ['kU/L'],
#  'Cystathionine': ['µmol/L', 'umol/L'],
#  'Cystathionine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Cystine': ['µmol/L', 'umol/L'],
#  'Cystine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Cytarabine C': ['mg/L'],
#  'Cytarabine U': ['mg/L'],
#  'Cèdre du Japon, t17': ['kU/L'],
#  'Céfaclor, c7': ['kU/L'],
#  'Céfazoline': ['mg/L'],
#  'Céfixime': ['mg/L'],
#  'Céfuroxime': ['mg/L'],
#  'Céleri, f85': ['kU/L'],
#  'Céleri, rApig1': ['kU/L'],
#  'Céruléoplasmine': ['g/L'],
#  'D-Dimères': ['µg/L', 'ug/L'],
#  'DFG (CKD-EPI)': ['mL/min/1,73m²', 'mL/min/{1.73_m2}'],
#  'DFG (MDRD)': ['mL/min/1,73m²', 'mL/min/{1.73_m2}'],
#  'DHEA': ['nmol/L', 'ng/mL'],
#  'Dabigatran': ['ng/mL'],
#  'Dactyle pelotonn, g3': ['kU/L'],
#  'Danaparoïde (Orgaran®)': ['UI/mL', '[IU]/mL'],
#  'Darunavir': ['ng/mL'],
#  'Datte, f289': ['kU/L'],
#  'Dattier, t214': ['kU/L'],
#  'Delavirdine': ['ng/mL'],
#  'Delta aminolévulinate': ['µmol/L', 'umol/L'],
#  'Delta aminolévulinate /24h': ['µmol/24H', 'umol/(24.h)'],
#  'Delta aminolévulinate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Delta-4-Androstènedione': ['nmol/L', 'ng/mL'],
#  'Dermatophagoides farinae, d2': ['kU/L'],
#  'Dermatophagoides microceras, d3': ['kU/L'],
#  'Dermatophagoides pteronyssinus, d1': ['kU/L'],
#  'Dermatophagoides pteronyssinus, nDer p1': ['kU/L'],
#  'Dermatophagoides pteronyssinus, rDer p10': ['kU/L'],
#  'Dermatophagoides pteronyssinus, rDer p2': ['kU/L'],
#  'Dextropropoxyphène': ['ng/mL'],
#  'Diazépam': ['µg/L', 'ug/L'],
#  'Didanosine': ['ng/mL'],
#  'Digoxine': ['µg/L', 'ug/L'],
#  'Dihydrocodéine': ['ng/mL'],
#  'Dihydrotestostérone (DHT)': ['nmol/L', 'ng/mL'],
#  'Diltiazem': ['ng/mL'],
#  'Dinde (plumes), e89': ['kU/L'],
#  'Dinde (viande) f284': ['kU/L'],
#  'Dipyridamole': ['ng/mL'],
#  'Disopyramide': ['ng/mL'],
#  'Dodécanedioate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Dopamine': ['nmol/L', 'pg/mL', 'µg/L', 'ug/L'],
#  'Dopamine /24h': ['nmol/24h', 'nmol/(24.h)', 'µg/24h', 'ug/(24.h)'],
#  'Dopamine/créatinine': ['nmol/mmol',
#   'nmol/L/mmol{creat}',
#   'µg/g',
#   'ug/g{creat}'],
#  'Dosage pondéral anti-RH': ['UI/mL', '[IU]/mL'],
#  'Dosage pondéral anti-RH1': ['UI/mL', '[IU]/mL'],
#  'Dosage pondéral anti-RH2': ['UI/mL', '[IU]/mL'],
#  'Dosage pondéral anti-RH3': ['UI/mL', '[IU]/mL'],
#  'Dosage pondéral anti-RH4': ['UI/mL', '[IU]/mL'],
#  'Dosage pondéral anti-RH5': ['UI/mL', '[IU]/mL'],
#  'Doxépine': ['ng/mL'],
#  'Duloxétine': ['ng/mL'],
#  'Décadiènedioate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Déchet de Soie, k73': ['kU/L'],
#  'Décènedioate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Déficit basal': ['mmol/L'],
#  "Délai d'abstinence": ['jours', 'd'],
#  'Délai de pousse': ['jours', 'J'],
#  'Dénombrement Bactérie': ['/µL', '/uL'],
#  'Désipramine': ['ng/mL'],
#  'EDDP': ['ng/mL'],
#  'Ecgonine méthylester': ['ng/mL'],
#  'Echinococcus, p2': ['kU/L'],
#  'Elastase fécale': ['µg/g', 'ug/g'],
#  'Empereur, f412': ['kU/L'],
#  'Enzyme de conversion': ['UI/L', '[IU]/L'],
#  'Enzyme de conversion (LCR)': ['UI/L', 'u[IU]/L'],
#  'Epicoccum purpurascens, m14': ['kU/L'],
#  'Epstein barr virus Ac capside IgG': ['UA/mL', "[arb'U]/mL"],
#  'Epstein barr virus Ac capside IgM': ['UA/mL', "[arb'U]/mL"],
#  'Erythrocytes': ['10*3 cell/µL', '10*3/uL'],
#  'Erythrocytes nucléés': ['%'],
#  'Erythropoïétine (EPO)': ['UI/L', '[IU]/L'],
#  'Escargot, f314': ['kU/L'],
#  'Espadon, f312': ['kU/L'],
#  'Estazolam': ['ng/mL'],
#  'Estradiol': ['pmol/L', 'pg/mL'],
#  'Estragon, f272': ['kU/L'],
#  'Estrone': ['pmol/L', 'pg/mL'],
#  'Etanercept': ['µg/mL', 'ug/mL'],
#  'Ethanolamine': ['µmol/L', 'umol/L'],
#  'Ethosuximide': ['mg/L'],
#  'Eucalyptus, t18': ['kU/L'],
#  'Euroglyphus maynei, d74': ['kU/L'],
#  'Excès de base artériel': ['mmol/L'],
#  'Excès de base capillaire': ['mmol/L'],
#  'Excès de base sang de cordon artériel': ['mmol/L'],
#  'Excès de base sang de cordon veineux': ['mmol/L'],
#  'Excès de base veineux': ['mmol/L'],
#  'FSH': ['UI/L', '[IU]/L'],
#  'FSH urinaire': ['UI/L', '[IU]/L'],
#  'FSH urinaire /24h': ['UI/24H', '[IU]/(24.h)'],
#  'Facteur II': ['%'],
#  'Facteur IX': ['%'],
#  'Facteur V': ['%'],
#  'Facteur VII': ['%'],
#  'Facteur VII+X': ['%'],
#  'Facteur VIII': ['%'],
#  'Facteur X': ['%'],
#  'Facteur XI': ['%'],
#  'Facteur XII': ['%'],
#  'Facteur XIII': ['%'],
#  'Facteurs rhumatoïdes': ['UI/mL', '[IU]/mL'],
#  'Facteurs rhumatoïdes IgA': ['UI/mL', '[IU]/mL'],
#  'Facteurs rhumatoïdes IgM': ['UI/mL', '[IU]/mL'],
#  'Fausse ambroisie, w4': ['kU/L'],
#  'Felbamate': ['mg/L'],
#  'Fenouil (graine), f219': ['kU/L'],
#  'Fenouil, f276': ['kU/L'],
#  'Fentanyl': ['ng/mL'],
#  'Fer sérique': ['µmol/L', 'umol/L', 'mg/L'],
#  'Ferritine': ['µg/L', 'ug/L'],
#  'Feuille de tabac, o201': ['kU/L'],
#  'Fibrinogène': ['g/L'],
#  'Fibrinogène  pondéral': ['g/L'],
#  'Fibrinogène antigène': ['mg/dL'],
#  'Ficus, k81': ['kU/L'],
#  'Figue, f328': ['kU/L'],
#  'Filao, t73': ['kU/L'],
#  'Flet, f147': ['kU/L'],
#  'Flouve odorante, g1': ['kU/L'],
#  'Fluconazole': ['mg/L'],
#  'Flunitrazépam': ['ng/mL'],
#  'Fluoxétine': ['ng/mL'],
#  'Flurazépam': ['ng/mL'],
#  'Flétan, f303': ['kU/L'],
#  'Folates': ['nmol/L', 'µg/L', 'ug/L'],
#  'Folates érythrocytaires': ['nmol/L', 'µg/L', 'ug/L'],
#  'Fondaparinux': ['ng/mL'],
#  'Formaldéhyde, k80': ['kU/L'],
#  'Fourmi rouge, i70': ['kU/L'],
#  'Fraction anormale': ['%'],
#  'Fraise, f44': ['kU/L'],
#  'Framboise, f343': ['kU/L'],
#  'Frelon asiatique (venin)': ['kU/L'],
#  'Fromage (fermenté), f82': ['kU/L'],
#  'Fromage (pâte cuite), f81': ['kU/L'],
#  'Fromental, g204': ['kU/L'],
#  'Fructosamine': ['µmol/L', 'umol/L'],
#  'Fructose': ['mmol/L'],
#  'Fruit de la passion, f294': ['kU/L'],
#  'Frêne blanc, t15': ['kU/L'],
#  'Frêne, t25': ['kU/L'],
#  'Fumarate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Furet, e217': ['kU/L'],
#  'Fusarium moniliforme, m9': ['kU/L'],
#  'Fénugrec, f305': ['kU/L'],
#  'Fétuque des prés, g4': ['kU/L'],
#  'Gabapentine': ['mg/L'],
#  'Gamma aminobutyrate': ['µmol/L', 'umol/L'],
#  'Gamma aminobutyrate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Gamma globulines': ['g/L', 'mg/L'],
#  'Gamma globulines %': ['%'],
#  'Gamma glutamyl transférase (GGT)': ['UI/L', '[IU]/L'],
#  'Gamma hydroxybutyrate (GHB)': ['mg/L'],
#  'Gamma hydroxybutyrate urinaire': ['mg/L'],
#  'Ganciclovir': ['mg/L'],
#  'Gastrine': ['pmol/L', 'ng/L'],
#  'Gentamicine': ['mg/L'],
#  'Gentamicine - Pic': ['mg/L'],
#  'Gentamicine - Taux résiduel': ['mg/L'],
#  'Genévrier, t6': ['kU/L'],
#  'Genêt à balai, t55': ['kU/L'],
#  'Gerbille, e209': ['kU/L'],
#  'Gingembre, f270': ['kU/L'],
#  'Globuline': ['g/L'],
#  'Globulines': ['g/L'],
#  'Glucose': ['mmol/L', 'g/L', 'mg/L'],
#  'Glucose - Liquide de ponction': ['mmol/L'],
#  'Glucose LCR': ['mmol/L', 'g/L'],
#  'Glucose post prandial': ['mmol/L', 'g/L'],
#  'Glucose urinaire': ['g/L', 'mmol/L'],
#  'Glucose urinaire /24h': ['mmol/24h', 'mmol/(24.h)', 'g/24h', 'g/(24.h)'],
#  'Glucose à jeun': ['mmol/L', 'g/L'],
#  'Glutaconate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Glutamate': ['µmol/L', 'umol/L'],
#  'Glutamate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Glutamine': ['µmol/L', 'umol/L'],
#  'Glutamine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Glutarate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Gluten, f79': ['kU/L'],
#  'Glycine': ['µmol/L', 'umol/L'],
#  'Glycine/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Glycolate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Glycyphagus domesticus, d73': ['kU/L'],
#  'Glycérate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Glycérol': ['mmol/L', 'g/L'],
#  'Glyoxylate/créatinine': ['µmol/mmol créat', 'umol/mmol{creat}'],
#  'Golimumab': ['µg/mL', 'ug/mL'],
#  'Gomme arabique, f297': ['kU/L'],
#  ...}

# %%
# Récupérer la liste des marqueurs avec le nombre d'occurences
top_120_df = pd.read_csv('utils/results/top_120.csv')

# Garder que les marqueurs qui sont apparus au moins une fois
top_50_df = top_120_df.drop('Unnamed: 0', axis=1)[:50]
top_50_list = list(map(lambda x : preprocess(x), list(top_50_df['grandeur'])))


# Modifier le dictionnaire des unités pour garder que ceux qui apparaissent
all_units = set()
units_found = {}
for key in units :
    normalized_key = preprocess(key)
    unit_lower = []
    for u in units[key]:
        all_units.add(u.lower())
        unit_lower += u.lower()
        
    if normalized_key in top_50_list:
        units_found[normalized_key] = unit_lower
        
all_units.add('t/l')
all_units.add('g/100ml')
all_units.add('/mm3')
all_units.add('giga/l')
all_units.add('u3')
all_units.add('/mm3')
all_units.add('picog.')
all_units.add('meg/l')
all_units.add('meq/l')
all_units.add('neg/ml')
all_units.add('10%/')
all_units.add('ng/nl')
all_units.remove('%')
len(all_units)
# Out:
# 153

# %% [markdown]
# # Récupérer les synonymes des marqueurs

# %%
synonymes = pd.read_excel("data/variable_biologique_bioLOINC.xlsx", sheet_name="CKD1")

# %%
synonymes
# Out:
#    Variable (abréviation)                           Variable  \
# 0                     ALB              Albuminurie volumique
# 1                  ALB24h                    Albuminurie 24h
# 2                     CRE            Créatininurie volumique
# 3                  CRE24h                  Créatininurie 24h
# 4                     PRO              Protéinurie volumique
# 5                  PRO24h                    Protéinurie 24h
# 6                     RAC  Rapport albuminurie/créatininurie
# 7                     RPC  Rapport protéinurie/créatininurie
# 8                     DFG   Débit de filtration glomérulaire
# 9                    HEMO                        Hémoglobine
# 10                  LEUCO                         Leucocytes
# 11                   POLY        Polynucléaires neutrophiles
# 12                   LYMP                        Lymphocytes
# 13                   PLAQ                         Plaquettes
# 14                    CRP                Protéine C réactive
# 15                   ASAT  ASAT,  Aspartate aminotransférase
# 16                   ALAT     ALAT, Alanine aminotransférase
# 17                    GGT                           Gamma GT
# 18                    PAL         PAL (phosphatase alcaline)
# 19                    POT                Potassium (sanguin)
# 20                    SOD                   Sodium (sanguin)
# 21                    FER                          Ferritine
# 22                   ALBH                Albumine (sanguine)
# 23                    GLY                    Glycémie à jeun
# 24                  HbA1c                              HbA1c
# 25                    TSH                                TSH
# 26                   BHCG                              B-HCG
#
#                                 Synonymes et exemples  \
# 0   Albuminurie, Albumine (urines), Albumine urina...
# 1   Albuminurie, Albumine (urines), Albumine urina...
# 2   Créatininurie, Créatinine (urines), Créatinine...
# 3   Créatininurie, Créatinine (urines), Créatinine...
# 4   Protéinuries, Protéines (urines), Protéines ur...
# 5   Protéinuries, Protéines (urines), Protéines ur...
# 6   Rapport albuminurie/créatininurie, Rapport alb...
# 7          Rapport protéines/créatinine urinaire, ...
# 8   Débit de filtration glomérulaire, DFG, glomeru...
# 9   Hb, Hémoglobine (attention a ne pas capter l'h...
# 10                                         Leucocytes
# 11  Polynucléaires neutrophiles, granulocytes neut...
# 12                                  Lymphocytes ; Lc
# 13                    Plaquettes ; Plt ; Thrombocytes
# 14                          CRP , Protéine C réactive
# 15             Aspartate aminotransférase, ASAT, SGOT
# 16               Alainie aminotransférase, ALAT, SGPT
# 17          Gamma glutamyl transférase, Gamma GT, GGT
# 18                    Phosphatase(s) alcaline(s), PAL
# 19                         Potassium, K, K+, Kaliémie
# 20                          Sodium, Na, Na+, Natrémie
# 21                            Ferritine, Ferritinémie
# 22                              Albumine, Albuminémie
# 23                               Glycémie à jeun, GAJ
# 24  Hémoglobine glyquée, Hémoglobine glycosylée, H...
# 25                        Thyréostimuline, TSH, TSHus
# 26  Béta HCG, Béta human chorionic gonadotrophine,...
#
#                                                RegExp  Unité (cible)  \
# 0   [aA]lbuminurie|([aA]lbumin.{1,10}[uU]rin[^ ]*)...           mg/L
# 1   [aA]lbuminurie|([aA]lbumin.{1,10}[uU]rin[^ ]*)...         mg/24h
# 2   [cC]r.atininurie|([[cR]r.atinin.{0,8}[uU]ri[^ ...            g/L
# 3   [cC]r.atininurie|([[cR]r.atinin.{0,8}[uU]ri[^ ...          g/24h
# 4      [pP]rot.inurie|([pP]rot.in.{1,10}[uU]rin[^ ]*)           mg/L
# 5      [pP]rot.inurie|([pP]rot.in.{1,10}[uU]rin[^ ]*)         mg/24h
# 6   (RAC )|(ACR )|([rR]apport [micro]{0,5}?[aA]lbu...           mg/g
# 7   (RPC )|([rR]apport [pP]rot.in.{1,10}[cC]r.atin...           mg/g
# 8   (DFG )|(GFR )|(CKD[- ]?EPI)|([dD].bit.{1,5}[fF...  mL/min/1,73m2
# 9        (H[bB] )|([hH].moglobine(?!.{0,4}glyc[^ ]*))           g/dL
# 10                                [lL]eucoc[iy]te[s]?            G/L
# 11  ([pP]olynucl.air.{1,5}[nN]eutr[^ ]*)|([gG]ranu...            G/L
# 12                               [lL]ymphoc[iy]te[s]?            G/L
# 13        (Plt)|([tT]hromboc[iy]te[s]?)|[pP]laquettes            G/L
# 14  (CRP)|([pP]rot.ine.{1,3}[cC].{1,3}[rR].active)...           mg/L
# 15   (ASAT)|([aA]spartat.{1,5}[aA]minotransf.ra[^ ]+)           UI/L
# 16   (ALAT) |([aA]lanine.{1,5}[aA]minotransf.ra[^ ]+)           UI/L
# 17  [(amma)gGγ].{0,5}[gG][tT]|([(amma)gGγ].?[gG]lu...           UI/L
# 18        (PAL)|([pP]hosphatase.{1,3}[aA]lcaline[s]?)          UI/L
# 19              ([kK][+]? )|[pP]otassium|[kK]al?i.mie         mmol/L
# 20                      (Na.? )|[sS]odium|[nN]atr.mie         mmol/L
# 21                                   [fF]er+itin[^ ]+           µg/L
# 22      [aA]lbumin.mie|([aA]lbumin(?!.{0,4}uri[^ ]*))            g/L
# 23               (G[Aaà]J )|[gG]l[y.i]c.mie.{1,5}jeun            g/L
# 24  H[bB]A1[cC]|([hH].moglobin.{1,4}[gG]l[iy]c[^ ]...              %
# 25           (T[.]?S[.]?H[.]?)|[tT]h?[iy]r.ostimuline          mUI/L
# 26  H[.]?C[.]?G[.]?|([bB].ta.{1,3}human.{1,3}chori...           UI/L
#
#                     {RegExp unité, facteur d'échelle}  \
# 0   {mg([ \/]|( par ))L, 1};{( g)([ \/]|( par ))L,...
# 1   {mg([ \/]|( par ))24 ?h,1};{( g)([ \/]|( par )...
# 2   {( g)([ \/]|( par ))L,1};{mg([ \/]|( par ))L, ...
# 3   {( g)([ \/]|( par ))24 ?h,1};{mg([ \/]|( par )...
# 4   {mg([ \/]|( par ))L, 1} ;{g([ \/]|( par ))L,0....
# 5   {mg([ \/]|( par ))24 ?h,1}; {g([ \/]|( par ))2...
# 6   {mg([ \/]|( par ))mmol,1};{g([ \/]|( par ))mol,1}
# 7   {mg([ \/]|( par ))mmol,1};{g([ \/]|( par ))mol,1}
# 8                                       mL/mi?n/1.73m
# 9                                      g/dL ; g/100mL
# 10                              10^9/L ; G/L ; giga/L
# 11                              10^9/L ; G/L ; giga/L
# 12                           10^9/L ; G/L ; [gG]iga/L
# 13                              10^9/L ; G/L ; giga/L
# 14                                               mg/L
# 15                                  UI/L ; U/L ; IU/L
# 16                                  UI/L ; U/L ; IU/L
# 17                                  UI/L ; U/L ; IU/L
# 18                                  UI/L ; U/L ; IU/L
# 19                                             mmol/L
# 20                                             mmol/L
# 21                                               µg/L
# 22                                                g/L
# 23                                       g/L ; mmol/L
# 24                                                  %
# 25                               mUI/L ; mU/L ; mIU/L
# 26                                  UI/L ; U/L ; IU/L
#
#    Plage valeur plausibles (unité cible)  LOINC  Unité trouvé  \
# 0                                0-10000    NaN           NaN
# 1                                0-10000    NaN           NaN
# 2                                   0-10    NaN        umol/L
# 3                                   0-10    NaN           NaN
# 4                                0-10000    NaN           NaN
# 5                                0-10000    NaN           NaN
# 6                                0-10000    NaN           NaN
# 7                                0-10000    NaN           NaN
# 8                                  0-300    NaN           NaN
# 9                                   0-30    NaN           NaN
# 10                                 0-200    NaN      /ml;/mm3
# 11                                 0-200    NaN          /mm3
# 12                                 0-200    NaN          /mm3
# 13                                0-5000    NaN          /mm3
# 14                                0-1000    NaN           NaN
# 15                              0-100000    NaN           NaN
# 16                              0-100000    NaN           U/I
# 17                              0-100000    NaN           NaN
# 18                              0-100000    NaN           NaN
# 19                                  0-20    NaN           NaN
# 20                               100-200    NaN           NaN
# 21                               0-10000    NaN         ng/mL
# 22                                 0-100    NaN           NaN
# 23                                  0-20    NaN           NaN
# 24                                  0-25    NaN           NaN
# 25                                 0-100    NaN  UI/mL;uUI/mL
# 26                              0-500000    NaN           NaN
#
#                              Unnamed: 9  \
# 0   microalbuminurie : autre variable ?
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                utile?
# 8                filtrer les formules ?
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
#
#                               Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0                                     NaN          NaN          NaN
# 1                                     NaN          NaN          NaN
# 2                                     NaN          NaN          NaN
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# 5                                     NaN          NaN          NaN
# 6                                     NaN          NaN          NaN
# 7                                     NaN          NaN          NaN
# 8   {FRP34, 01/01/2023, ALB, 34, 5245-45}          NaN          NaN
# 9                                     NaN          NaN          NaN
# 10                                    NaN          NaN          NaN
# 11                                    NaN          NaN          NaN
# 12                                    NaN          NaN          NaN
# 13                                    NaN          NaN          NaN
# 14                                    NaN          NaN          NaN
# 15                                    NaN          NaN          NaN
# 16                                    NaN          NaN          NaN
# 17                                    NaN          NaN          NaN
# 18                                    NaN          NaN          NaN
# 19                                    NaN          NaN          NaN
# 20                                    NaN          NaN          NaN
# 21                                    NaN          NaN          NaN
# 22                                    NaN          NaN          NaN
# 23                                    NaN          NaN          NaN
# 24                                    NaN          NaN          NaN
# 25                                    NaN          NaN          NaN
# 26                                    NaN          NaN          NaN
#
#                                           Unnamed: 13
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Regarder si mention de CKD-EPI ou MDRD, Exclur...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN

# %%
regex_syn = synonymes.iloc[:7]['RegExp'].tolist()

list_regex_dict = []
for regex_unit in synonymes['{RegExp unité, facteur d\'échelle}']:
    unit_dict_list = []
    # Ex: {mg([ \/]|( par ))L, 1};{( g)([ \/]|( par ))L,0.001}
    for r_split in regex_unit.split(';'):
        # r_split ex: '{mg([ \/]|( par ))L, 1}'
        unit_dict = {}
        r_split_clean = r_split.replace('{', '').replace('}', '').strip()
            
        r_splits = r_split_clean.split(',')
        # ex r_splits : ['mg([ \/]|( par ))L', '1']
        
        if len(r_splits) > 1:
            unit_dict[r_splits[0]] = r_splits[1]
        else:
            unit_dict[r_splits[0]] = 1
        unit_dict_list.append(unit_dict)
    list_regex_dict.append(unit_dict_list)

synonymes['Regex_unité_facteur'] = list_regex_dict
synonymes
# Out:
#    Variable (abréviation)                           Variable  \
# 0                     ALB              Albuminurie volumique
# 1                  ALB24h                    Albuminurie 24h
# 2                     CRE            Créatininurie volumique
# 3                  CRE24h                  Créatininurie 24h
# 4                     PRO              Protéinurie volumique
# 5                  PRO24h                    Protéinurie 24h
# 6                     RAC  Rapport albuminurie/créatininurie
# 7                     RPC  Rapport protéinurie/créatininurie
# 8                     DFG   Débit de filtration glomérulaire
# 9                    HEMO                        Hémoglobine
# 10                  LEUCO                         Leucocytes
# 11                   POLY        Polynucléaires neutrophiles
# 12                   LYMP                        Lymphocytes
# 13                   PLAQ                         Plaquettes
# 14                    CRP                Protéine C réactive
# 15                   ASAT  ASAT,  Aspartate aminotransférase
# 16                   ALAT     ALAT, Alanine aminotransférase
# 17                    GGT                           Gamma GT
# 18                    PAL         PAL (phosphatase alcaline)
# 19                    POT                Potassium (sanguin)
# 20                    SOD                   Sodium (sanguin)
# 21                    FER                          Ferritine
# 22                   ALBH                Albumine (sanguine)
# 23                    GLY                    Glycémie à jeun
# 24                  HbA1c                              HbA1c
# 25                    TSH                                TSH
# 26                   BHCG                              B-HCG
#
#                                 Synonymes et exemples  \
# 0   Albuminurie, Albumine (urines), Albumine urina...
# 1   Albuminurie, Albumine (urines), Albumine urina...
# 2   Créatininurie, Créatinine (urines), Créatinine...
# 3   Créatininurie, Créatinine (urines), Créatinine...
# 4   Protéinuries, Protéines (urines), Protéines ur...
# 5   Protéinuries, Protéines (urines), Protéines ur...
# 6   Rapport albuminurie/créatininurie, Rapport alb...
# 7          Rapport protéines/créatinine urinaire, ...
# 8   Débit de filtration glomérulaire, DFG, glomeru...
# 9   Hb, Hémoglobine (attention a ne pas capter l'h...
# 10                                         Leucocytes
# 11  Polynucléaires neutrophiles, granulocytes neut...
# 12                                  Lymphocytes ; Lc
# 13                    Plaquettes ; Plt ; Thrombocytes
# 14                          CRP , Protéine C réactive
# 15             Aspartate aminotransférase, ASAT, SGOT
# 16               Alainie aminotransférase, ALAT, SGPT
# 17          Gamma glutamyl transférase, Gamma GT, GGT
# 18                    Phosphatase(s) alcaline(s), PAL
# 19                         Potassium, K, K+, Kaliémie
# 20                          Sodium, Na, Na+, Natrémie
# 21                            Ferritine, Ferritinémie
# 22                              Albumine, Albuminémie
# 23                               Glycémie à jeun, GAJ
# 24  Hémoglobine glyquée, Hémoglobine glycosylée, H...
# 25                        Thyréostimuline, TSH, TSHus
# 26  Béta HCG, Béta human chorionic gonadotrophine,...
#
#                                                RegExp  Unité (cible)  \
# 0   [aA]lbuminurie|([aA]lbumin.{1,10}[uU]rin[^ ]*)...           mg/L
# 1   [aA]lbuminurie|([aA]lbumin.{1,10}[uU]rin[^ ]*)...         mg/24h
# 2   [cC]r.atininurie|([[cR]r.atinin.{0,8}[uU]ri[^ ...            g/L
# 3   [cC]r.atininurie|([[cR]r.atinin.{0,8}[uU]ri[^ ...          g/24h
# 4      [pP]rot.inurie|([pP]rot.in.{1,10}[uU]rin[^ ]*)           mg/L
# 5      [pP]rot.inurie|([pP]rot.in.{1,10}[uU]rin[^ ]*)         mg/24h
# 6   (RAC )|(ACR )|([rR]apport [micro]{0,5}?[aA]lbu...           mg/g
# 7   (RPC )|([rR]apport [pP]rot.in.{1,10}[cC]r.atin...           mg/g
# 8   (DFG )|(GFR )|(CKD[- ]?EPI)|([dD].bit.{1,5}[fF...  mL/min/1,73m2
# 9        (H[bB] )|([hH].moglobine(?!.{0,4}glyc[^ ]*))           g/dL
# 10                                [lL]eucoc[iy]te[s]?            G/L
# 11  ([pP]olynucl.air.{1,5}[nN]eutr[^ ]*)|([gG]ranu...            G/L
# 12                               [lL]ymphoc[iy]te[s]?            G/L
# 13        (Plt)|([tT]hromboc[iy]te[s]?)|[pP]laquettes            G/L
# 14  (CRP)|([pP]rot.ine.{1,3}[cC].{1,3}[rR].active)...           mg/L
# 15   (ASAT)|([aA]spartat.{1,5}[aA]minotransf.ra[^ ]+)           UI/L
# 16   (ALAT) |([aA]lanine.{1,5}[aA]minotransf.ra[^ ]+)           UI/L
# 17  [(amma)gGγ].{0,5}[gG][tT]|([(amma)gGγ].?[gG]lu...           UI/L
# 18        (PAL)|([pP]hosphatase.{1,3}[aA]lcaline[s]?)          UI/L
# 19              ([kK][+]? )|[pP]otassium|[kK]al?i.mie         mmol/L
# 20                      (Na.? )|[sS]odium|[nN]atr.mie         mmol/L
# 21                                   [fF]er+itin[^ ]+           µg/L
# 22      [aA]lbumin.mie|([aA]lbumin(?!.{0,4}uri[^ ]*))            g/L
# 23               (G[Aaà]J )|[gG]l[y.i]c.mie.{1,5}jeun            g/L
# 24  H[bB]A1[cC]|([hH].moglobin.{1,4}[gG]l[iy]c[^ ]...              %
# 25           (T[.]?S[.]?H[.]?)|[tT]h?[iy]r.ostimuline          mUI/L
# 26  H[.]?C[.]?G[.]?|([bB].ta.{1,3}human.{1,3}chori...           UI/L
#
#                     {RegExp unité, facteur d'échelle}  \
# 0   {mg([ \/]|( par ))L, 1};{( g)([ \/]|( par ))L,...
# 1   {mg([ \/]|( par ))24 ?h,1};{( g)([ \/]|( par )...
# 2   {( g)([ \/]|( par ))L,1};{mg([ \/]|( par ))L, ...
# 3   {( g)([ \/]|( par ))24 ?h,1};{mg([ \/]|( par )...
# 4   {mg([ \/]|( par ))L, 1} ;{g([ \/]|( par ))L,0....
# 5   {mg([ \/]|( par ))24 ?h,1}; {g([ \/]|( par ))2...
# 6   {mg([ \/]|( par ))mmol,1};{g([ \/]|( par ))mol,1}
# 7   {mg([ \/]|( par ))mmol,1};{g([ \/]|( par ))mol,1}
# 8                                       mL/mi?n/1.73m
# 9                                      g/dL ; g/100mL
# 10                              10^9/L ; G/L ; giga/L
# 11                              10^9/L ; G/L ; giga/L
# 12                           10^9/L ; G/L ; [gG]iga/L
# 13                              10^9/L ; G/L ; giga/L
# 14                                               mg/L
# 15                                  UI/L ; U/L ; IU/L
# 16                                  UI/L ; U/L ; IU/L
# 17                                  UI/L ; U/L ; IU/L
# 18                                  UI/L ; U/L ; IU/L
# 19                                             mmol/L
# 20                                             mmol/L
# 21                                               µg/L
# 22                                                g/L
# 23                                       g/L ; mmol/L
# 24                                                  %
# 25                               mUI/L ; mU/L ; mIU/L
# 26                                  UI/L ; U/L ; IU/L
#
#    Plage valeur plausibles (unité cible)  LOINC  Unité trouvé  \
# 0                                0-10000    NaN           NaN
# 1                                0-10000    NaN           NaN
# 2                                   0-10    NaN        umol/L
# 3                                   0-10    NaN           NaN
# 4                                0-10000    NaN           NaN
# 5                                0-10000    NaN           NaN
# 6                                0-10000    NaN           NaN
# 7                                0-10000    NaN           NaN
# 8                                  0-300    NaN           NaN
# 9                                   0-30    NaN           NaN
# 10                                 0-200    NaN      /ml;/mm3
# 11                                 0-200    NaN          /mm3
# 12                                 0-200    NaN          /mm3
# 13                                0-5000    NaN          /mm3
# 14                                0-1000    NaN           NaN
# 15                              0-100000    NaN           NaN
# 16                              0-100000    NaN           U/I
# 17                              0-100000    NaN           NaN
# 18                              0-100000    NaN           NaN
# 19                                  0-20    NaN           NaN
# 20                               100-200    NaN           NaN
# 21                               0-10000    NaN         ng/mL
# 22                                 0-100    NaN           NaN
# 23                                  0-20    NaN           NaN
# 24                                  0-25    NaN           NaN
# 25                                 0-100    NaN  UI/mL;uUI/mL
# 26                              0-500000    NaN           NaN
#
#                              Unnamed: 9  \
# 0   microalbuminurie : autre variable ?
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                utile?
# 8                filtrer les formules ?
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
#
#                               Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0                                     NaN          NaN          NaN
# 1                                     NaN          NaN          NaN
# 2                                     NaN          NaN          NaN
# 3                                     NaN          NaN          NaN
# 4                                     NaN          NaN          NaN
# 5                                     NaN          NaN          NaN
# 6                                     NaN          NaN          NaN
# 7                                     NaN          NaN          NaN
# 8   {FRP34, 01/01/2023, ALB, 34, 5245-45}          NaN          NaN
# 9                                     NaN          NaN          NaN
# 10                                    NaN          NaN          NaN
# 11                                    NaN          NaN          NaN
# 12                                    NaN          NaN          NaN
# 13                                    NaN          NaN          NaN
# 14                                    NaN          NaN          NaN
# 15                                    NaN          NaN          NaN
# 16                                    NaN          NaN          NaN
# 17                                    NaN          NaN          NaN
# 18                                    NaN          NaN          NaN
# 19                                    NaN          NaN          NaN
# 20                                    NaN          NaN          NaN
# 21                                    NaN          NaN          NaN
# 22                                    NaN          NaN          NaN
# 23                                    NaN          NaN          NaN
# 24                                    NaN          NaN          NaN
# 25                                    NaN          NaN          NaN
# 26                                    NaN          NaN          NaN
#
#                                           Unnamed: 13  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Regarder si mention de CKD-EPI ou MDRD, Exclur...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
#
#                                   Regex_unité_facteur
# 0   [{'mg([ \/]|( par ))L': ' 1'}, {'( g)([ \/]|( ...
# 1   [{'mg([ \/]|( par ))24 ?h': '1'}, {'( g)([ \/]...
# 2   [{'( g)([ \/]|( par ))L': '1'}, {'mg([ \/]|( p...
# 3   [{'( g)([ \/]|( par ))24 ?h': '1'}, {'mg([ \/]...
# 4   [{'mg([ \/]|( par ))L': ' 1'}, {'g([ \/]|( par...
# 5   [{'mg([ \/]|( par ))24 ?h': '1'}, {'g([ \/]|( ...
# 6   [{'mg([ \/]|( par ))mmol': '1'}, {'g([ \/]|( p...
# 7   [{'mg([ \/]|( par ))mmol': '1'}, {'g([ \/]|( p...
# 8                              [{'mL/mi?n/1.73m': 1}]
# 9                       [{'g/dL': 1}, {'g/100mL': 1}]
# 10         [{'10^9/L': 1}, {'G/L': 1}, {'giga/L': 1}]
# 11         [{'10^9/L': 1}, {'G/L': 1}, {'giga/L': 1}]
# 12      [{'10^9/L': 1}, {'G/L': 1}, {'[gG]iga/L': 1}]
# 13         [{'10^9/L': 1}, {'G/L': 1}, {'giga/L': 1}]
# 14                                      [{'mg/L': 1}]
# 15             [{'UI/L': 1}, {'U/L': 1}, {'IU/L': 1}]
# 16             [{'UI/L': 1}, {'U/L': 1}, {'IU/L': 1}]
# 17             [{'UI/L': 1}, {'U/L': 1}, {'IU/L': 1}]
# 18             [{'UI/L': 1}, {'U/L': 1}, {'IU/L': 1}]
# 19                                    [{'mmol/L': 1}]
# 20                                    [{'mmol/L': 1}]
# 21                                      [{'µg/L': 1}]
# 22                                       [{'g/L': 1}]
# 23                        [{'g/L': 1}, {'mmol/L': 1}]
# 24                                         [{'%': 1}]
# 25          [{'mUI/L': 1}, {'mU/L': 1}, {'mIU/L': 1}]
# 26             [{'UI/L': 1}, {'U/L': 1}, {'IU/L': 1}]

# %% [markdown]
# # Itérer sur les paragraphes pour trouver les marqueurs

# %%
def search_marqueur(words, start):
    line = ' '.join(words[start:])
    marqueur = None
    regex = None
    for reg in regex_syn:
        marqueur = re.search(r'(?i)'+reg, line)
        if marqueur:
            marqueur = marqueur.group()
            regex = reg
            break
            
    if not marqueur :
        return -1, None, None
    
    marqueur_splits = marqueur.split()
    index_marqueur = -1
    
    for i in range(len(words[start:])):
        if marqueur_splits[-1] in words[start:][i]:
            index_marqueur = i
            
    return index_marqueur, marqueur, regex

pattern = re.compile('^[<>]?[0-9]+[.,]?[0-9]*')

def search_unit(words, start, regex):        
    for i in range(start, len(words)):
        if words[i] == '%' and regex == 'H[bB]A1[cC]|([hH].moglobin.{1,4}[gG]l[iy]c[^ ]*)|[hH].moglobine [Aa]1[cC]':
            return '%', i
        elif words[i].lower() in all_units:
            return words[i].lower(), i
    return None, -1

def search_value(words, start, end):
    index = end
    while index > 0 and re.search('^[<>]?[0-9]+[.,]?[0-9]*', words[index-1]) != None:
        index-=1
        
    # Vérifier si la valeur est après l'unité
    """if index < start:
        index = end
        while index < len(words) and bool(pattern.match(words[index])) is True:
            index += 1
        return ' '.join(words[end + 1:index])"""
    return ' '.join(words[index:end])

# %%
def extract_values(doc):
    """
        doc : list of dict
    """
    values_found = {}
    for page in doc :
        for words in page.values():
            # Etape 1 : trouver le marqueur
            index_marqueur, marqueur, marqueur_regex = search_marqueur(words, 0)
            while index_marqueur != -1 :            
                # Etape 2 : trouver l'unité avec bioloinc
                unit_in_doc, index_unit = search_unit(words, index_marqueur, marqueur_regex)
                if index_unit == -1:
                    break
                        
                # Etape 4 : récupérer la valeur qui est entre le marqueur et l'unité
                value = search_value(words, index_marqueur + 1, index_unit)
                if value == None:
                    break
                        
                """# Etape 5 : si l'unité est % alors on vérifie s'il y a le mot 'soit' ou ':' juste après
                if unit_in_doc == '%' and (words[index_unit + 1] == 'soit' or words[index_unit + 1] == ':'):
                    index_unit, unit_in_doc = search_unit(words, index_unit+2, marqueur)
                    value = search_value(words, index_marqueur, index_unit)
                    if value == None or index_unit == -1 :
                        break"""

                # Etape 6 : stocker dans un dictionnaire
                # Si le marqueur est dans les 50 marqueurs 
                #if marqueur in top_50_list :
                values_found[preprocess(marqueur).strip()] = value.replace(" ", "") + unit_in_doc
                
                # On relance pour vérifier s'il y a d'autres marqueurs sur la même ligne
                index_marqueur, marqueur, marqueur_regex = search_marqueur(words, index_unit + 1)

            
    return values_found

extract_values(docs[31])
# Out:
# /tmp/ipykernel_9079/3158420219.py:6: FutureWarning: Possible nested set at position 23
#   marqueur = re.search(r'(?i)'+reg, line)
# {}

# %%
for i in range(len(docs)) :
    print("Document index", i)
    print(extract_values(docs[i]))
    print('------------------')
# Out:
# Document index 0
# {'creatinine': '123umol/l'}
# ------------------
# Document index 1
# {}
# ------------------
# Document index 2
# {}
# ------------------
# Document index 3
# {'creatinine': '8,3mg/l'}
# ------------------
# Document index 4
# {}
# ------------------
# Document index 5
# {}
# ------------------
# Document index 6
# {'creatinine': '10,1mg/l'}
# ------------------
# Document index 7
# {'creatinine urinaire': '695mg/l', 'microalbuminurie': '3,3mg/l'}
# ------------------
# Document index 8
# {}
# ------------------
# Document index 9
# {}
# ------------------
# Document index 10
# {}
# ------------------
# Document index 11
# {}
# ------------------
# Document index 12
# {}
# ------------------
# Document index 13
# {}
# ------------------
# Document index 14
# {'creatinine': '9,0mg/l'}
# ------------------
# Document index 15
# {}
# ------------------
# Document index 16
# {}
# ------------------
# Document index 17
# {}
# ------------------
# Document index 18
# {}
# ------------------
# Document index 19
# {'proteinurie': '0,073g/l'}
# ------------------
# Document index 20
# {'creatinine': '6,8mg/l'}
# ------------------
# Document index 21
# {'creatinine': '62umol/l'}
# ------------------
# Document index 22
# {}
# ------------------
# Document index 23
# {}
# ------------------
# Document index 24
# {}
# ------------------
# Document index 25
# {}
# ------------------
# Document index 26
# {}
# ------------------
# Document index 27
# {'creatinine': '11,2mg/l'}
# ------------------
# Document index 28
# {}
# ------------------
# Document index 29
# {}
# ------------------
# Document index 30
# {}
# ------------------
# Document index 31
# {}
# ------------------
# Document index 32
# {}
# ------------------
# Document index 33
# {}
# ------------------
# Document index 34
# {}
# ------------------
# Document index 35
# {'creatinine': '8.7mg/l'}
# ------------------
# Document index 36
# {'creatinine': '10,1mg/l'}
# ------------------
# Document index 37
# {'creatinine': '8,4mg/l'}
# ------------------
# Document index 38
# {'creatinine': '43umol/l'}
# ------------------
# Document index 39
# {}
# ------------------
# Document index 40
# {'creatinine': '10,1mg/l'}
# ------------------
# Document index 41
# {}
# ------------------
# Document index 42
# {}
# ------------------
# Document index 43
# {'creatinine': '61umol/l'}
# ------------------
# Document index 44
# {'creatinine': '8,3mg/l'}
# ------------------
# Document index 45
# {}
# ------------------
# Document index 46
# {}
# ------------------
# Document index 47
# {}
# ------------------
# Document index 48
# {'creatinine': '83umol/l'}
# ------------------
# Document index 49
# {}
# ------------------
# Document index 50
# {}
# ------------------
# Document index 51
# {}
# ------------------
# Document index 52
# {}
# ------------------
# Document index 53
# {'proteinurie': '0,40g/l'}
# ------------------
# Document index 54
# {'creatinine': '104umol/l'}
# ------------------
# Document index 55
# {'creatininemie': '9,1mg/l', 'creatinine': '103ml/min'}
# ------------------
# Document index 56
# {'creatinine': '5,4mg/l', 'albumine': '94,77mg/l'}
# ------------------
# Document index 57
# {'creatinine': '6,7mg/l'}
# ------------------
# Document index 58
# {}
# ------------------
# Document index 59
# {}
# ------------------
# Document index 60
# {}
# ------------------
# Document index 61
# {'creatinine': '79umol/l'}
# ------------------
# Document index 62
# {}
# ------------------
# Document index 63
# {}
# ------------------
# Document index 64
# {}
# ------------------
# Document index 65
# {}
# ------------------
# Document index 66
# {'creatinine': '8.33mg/l'}
# ------------------
# Document index 67
# {}
# ------------------
# Document index 68
# {}
# ------------------
# Document index 69
# {}
# ------------------
# Document index 70
# {}
# ------------------
# Document index 71
# {}
# ------------------
# Document index 72
# {}
# ------------------
# Document index 73
# {}
# ------------------
# Document index 74
# {}
# ------------------
# Document index 75
# {'creatinine': '70,8umol/l'}
# ------------------
# Document index 76
# {'creatinine': '8,9mg/l'}
# ------------------
# Document index 77
# {}
# ------------------
# Document index 78
# {}
# ------------------
# Document index 79
# {}
# ------------------
# Document index 80
# {'creatinine': '78umol/l'}
# ------------------
# Document index 81
# {}
# ------------------
# Document index 82
# {}
# ------------------
# Document index 83
# {}
# ------------------
# Document index 84
# {}
# ------------------
# Document index 85
# {}
# ------------------
# Document index 86
# {'creatinine': '62umol/l'}
# ------------------
# Document index 87
# {}
# ------------------
# Document index 88
# {'proteinurie': '0,08g/l'}
# ------------------
# Document index 89
# {}
# ------------------
# Document index 90
# {}
# ------------------
# Document index 91
# {}
# ------------------
# Document index 92
# {}
# ------------------
# Document index 93
# {}
# ------------------
# Document index 94
# {'creatinine': '7,4mg/l'}
# ------------------
# Document index 95
# {}
# ------------------
# Document index 96
# {'creatinine': '49umol/l'}
# ------------------
# Document index 97
# {}
# ------------------
# Document index 98
# {}
# ------------------
# Document index 99
# {}
# ------------------
# Document index 100
# {}
# ------------------
# Document index 101
# {'creatinine': '6,9mg/l'}
# ------------------
# Document index 102
# {}
# ------------------
# Document index 103
# {'creatinine': '7,5mg/l', 'albumine': '40g/l'}
# ------------------
# Document index 104
# {}
# ------------------
# Document index 105
# {}
# ------------------
# Document index 106
# {'creatinine': '6,5mg/l'}
# ------------------
# Document index 107
# {}
# ------------------
# Document index 108
# {}
# ------------------
# Document index 109
# {'creatinine': '66umol/l'}
# ------------------
# Document index 110
# {}
# ------------------
# Document index 111
# {'proteinurie': '0,08g/l'}
# ------------------
# Document index 112
# {}
# ------------------
# Document index 113
# {}
# ------------------
# Document index 114
# {}
# ------------------
# Document index 115
# {}
# ------------------
# Document index 116
# {}
# ------------------
# Document index 117
# {}
# ------------------
# Document index 118
# {}
# ------------------
# Document index 119
# {'creatinine': '63umol/l'}
# ------------------
# Document index 120
# {}
# ------------------
# Document index 121
# {}
# ------------------
# Document index 122
# {}
# ------------------
# Document index 123
# {}
# ------------------
# Document index 124
# {}
# ------------------
# Document index 125
# {}
# ------------------
# Document index 126
# {}
# ------------------
# Document index 127
# {}
# ------------------
# Document index 128
# {}
# ------------------
# Document index 129
# {}
# ------------------
# Document index 130
# {}
# ------------------
# Document index 131
# {}
# ------------------
# Document index 132
# {}
# ------------------
# Document index 133
# {}
# ------------------
# Document index 134
# {}
# ------------------
# Document index 135
# {}
# ------------------
# Document index 136
# {}
# ------------------
# Document index 137
# {}
# ------------------
# Document index 138
# {'creatinine': '108umol/l'}
# ------------------
# Document index 139
# {'creatinine': '8,8mg/l'}
# ------------------
# Document index 140
# {}
# ------------------
# Document index 141
# {}
# ------------------
# Document index 142
# {}
# ------------------
# Document index 143
# {}
# ------------------
# Document index 144
# {'creatininemie': '9,3mg/l'}
# ------------------
# Document index 145
# {}
# ------------------
# Document index 146
# {}
# ------------------
# Document index 147
# {}
# ------------------
# Document index 148
# {'acr': 'a', 'creatinine': '10,6mg/l'}
# ------------------
# Document index 149
# {}
# ------------------
# Document index 150
# {}
# ------------------
# Document index 151
# {}
# ------------------
# Document index 152
# {}
# ------------------
# Document index 153
# {}
# ------------------
# Document index 154
# {}
# ------------------
# Document index 155
# {'proteinurie': '0,09g/l', 'creatinine urinaire': '9360umol/l'}
# ------------------
# Document index 156
# {}
# ------------------
# Document index 157
# {}
# ------------------
# Document index 158
# {}
# ------------------
# Document index 159
# {'proteinurie': 'g/l'}
# ------------------
# Document index 160
# {}
# ------------------
# Document index 161
# {'creatinine': '5,9mg/l'}
# ------------------
# Document index 162
# {'creatinine': '62umol/l'}
# ------------------
# Document index 163
# {}
# ------------------
# Document index 164
# {}
# ------------------
# Document index 165
# {}
# ------------------
# Document index 166
# {}
# ------------------
# Document index 167
# {'creatinine': '10,7mg/l', 'proteinurie': '0,07g/l', 'creatinine urinaire': '2282mg/l'}
# ------------------
# Document index 168
# {}
# ------------------
# Document index 169
# {}
# ------------------
# Document index 170
# {}
# ------------------
# Document index 171
# {}
# ------------------
# Document index 172
# {'proteinurie': '0.07g/l'}
# ------------------
# Document index 173
# {'creatinine': '5,6mg/l'}
# ------------------
# Document index 174
# {}
# ------------------
# Document index 175
# {}
# ------------------
# Document index 176
# {'creatinine': '85umol/l', 'creatinine urinaire': '25,04mmol/l', 'proteinurie': '0,24g/l', 'microalbuminurie': '36mg/l'}
# ------------------
# Document index 177
# {}
# ------------------
# Document index 178
# {}
# ------------------
# Document index 179
# {}
# ------------------
# Document index 180
# {}
# ------------------
# Document index 181
# {}
# ------------------
# Document index 182
# {}
# ------------------
# Document index 183
# {}
# ------------------
# Document index 184
# {}
# ------------------
# Document index 185
# {}
# ------------------
# Document index 186
# {}
# ------------------
# Document index 187
# {}
# ------------------
# Document index 188
# {'creatinine': '8,0mg/l'}
# ------------------
# Document index 189
# {}
# ------------------
# Document index 190
# {}
# ------------------
# Document index 191
# {'proteinurie': '0,15g/24h'}
# ------------------
# Document index 192
# {}
# ------------------
# Document index 193
# {}
# ------------------
# Document index 194
# {}
# ------------------
# Document index 195
# {'creatininemie': '8,3mg/l', 'creatinine': '89ml/min', 'albumine': '42,7g/l'}
# ------------------
# Document index 196
# {}
# ------------------
# Document index 197
# {}
# ------------------
# Document index 198
# {}
# ------------------
# Document index 199
# {}
# ------------------
# Document index 200
# {'creatinine': '63umol/l'}
# ------------------
# Document index 201
# {'creatinine': '59umol/l'}
# ------------------
# Document index 202
# {}
# ------------------
# Document index 203
# {}
# ------------------
# Document index 204
# {}
# ------------------
# Document index 205
# {}
# ------------------
# Document index 206
# {'creatinine': '12,2mg/l'}
# ------------------
# Document index 207
# {'creatinine': '6,9mg/l', 'creatinine urinaire': '868mg/l', 'microalbuminurie': '76,0mg/l'}
# ------------------
# Document index 208
# {}
# ------------------
# Document index 209
# {}
# ------------------
# Document index 210
# {}
# ------------------
# Document index 211
# {}
# ------------------
# Document index 212
# {}
# ------------------
# Document index 213
# {}
# ------------------
# Document index 214
# {}
# ------------------
# Document index 215
# {}
# ------------------
# Document index 216
# {}
# ------------------
# Document index 217
# {'creatinine': '6,8mg/l'}
# ------------------
# Document index 218
# {}
# ------------------
# Document index 219
# {}
# ------------------
# Document index 220
# {}
# ------------------
# Document index 221
# {}
# ------------------
# Document index 222
# {}
# ------------------
# Document index 223
# {}
# ------------------
# Document index 224
# {}
# ------------------
# Document index 225
# {'creatinine': '11,7mg/l', 'creatinine urinaire': '1154mg/l'}
# ------------------
# Document index 226
# {'proteinurie': '<0.07g/l'}
# ------------------
# Document index 227
# {}
# ------------------
# Document index 228
# {}
# ------------------
# Document index 229
# {}
# ------------------
# Document index 230
# {}
# ------------------
# Document index 231
# {}
# ------------------
# Document index 232
# {}
# ------------------
# Document index 233
# {}
# ------------------
# Document index 234
# {}
# ------------------
# Document index 235
# {'creatinine': '6.9mg/l'}
# ------------------
# Document index 236
# {}
# ------------------
# Document index 237
# {'proteinurie': '0.10g/l'}
# ------------------
# Document index 238
# {'creatinine': '6,9mg/l', 'albuminemie': '44g/l'}
# ------------------
# Document index 239
# {'creatinine': '5,3mg/l', 'albumine': '90,18mg/l'}
# ------------------
# Document index 240
# {}
# ------------------
# Document index 241
# {'creatinine': '57umol/l'}
# ------------------
# Document index 242
# {}
# ------------------
# Document index 243
# {}
# ------------------
# Document index 244
# {'creatinine': '8,5mg/l'}
# ------------------
# Document index 245
# {'creatinine': '9,4mg/l'}
# ------------------
# Document index 246
# {}
# ------------------
# Document index 247
# {'proteinurie': '185mg/l'}
# ------------------
# Document index 248
# {}
# ------------------
# Document index 249
# {}
# ------------------
# Document index 250
# {'creatinine': '7,4mg/l'}
# ------------------
# Document index 251
# {}
# ------------------
# Document index 252
# {}
# ------------------
# Document index 253
# {}
# ------------------
# Document index 254
# {}
# ------------------
# Document index 255
# {}
# ------------------
# Document index 256
# {}
# ------------------
# Document index 257
# {}
# ------------------
# Document index 258
# {}
# ------------------
# Document index 259
# {}
# ------------------
# Document index 260
# {}
# ------------------
# Document index 261
# {}
# ------------------
# Document index 262
# {}
# ------------------
# Document index 263
# {}
# ------------------
# Document index 264
# {}
# ------------------
# Document index 265
# {}
# ------------------
# Document index 266
# {}
# ------------------
# Document index 267
# {}
# ------------------
# Document index 268
# {}
# ------------------
# Document index 269
# {}
# ------------------
# Document index 270
# {}
# ------------------
# Document index 271
# {}
# ------------------
# Document index 272
# {'creatinine': '7,2mg/l', 'albumine': 'g/l'}
# ------------------
# Document index 273
# {}
# ------------------
# Document index 274
# {'albumine': '46,8g/l'}
# ------------------
# Document index 275
# {}
# ------------------
# Document index 276
# {}
# ------------------
# Document index 277
# {}
# ------------------
# Document index 278
# {}
# ------------------
# Document index 279
# {}
# ------------------
# Document index 280
# {}
# ------------------
# Document index 281
# {}
# ------------------
# Document index 282
# {'creatinine urinaire': '7.9mmol/l', 'proteinurie': '0.140g/l'}
# ------------------
# Document index 283
# {'creatinine': '76umol/l'}
# ------------------
# Document index 284
# {}
# ------------------
# Document index 285
# {}
# ------------------
# Document index 286
# {}
# ------------------
# Document index 287
# {}
# ------------------
# Document index 288
# {}
# ------------------
